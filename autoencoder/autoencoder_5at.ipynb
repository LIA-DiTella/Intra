# %%
from logging import raiseExceptions
from tokenize import Double
import networkx as nx
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import os
import numpy as np
from vec3 import Vec3
import meshplot as mp
import torch
torch.manual_seed(125)
import random
random.seed(125)
import torch_f as torch_f

# %%
def count_fn(f):
    def wrapper(*args, **kwargs):
        wrapper.count += 1
        return f(*args, **kwargs)
    wrapper.count = 0
    return wrapper

# %% [markdown]
# Clase Nodo

# %%
class Node:
    """
    Class Node
    """
    def __init__(self, value, radius, left = None, right = None, position = None, cl_prob= None, ce = None, mse = None, level = None, treelevel = None):
        self.left = left
        self.data = value
        self.radius = radius
        self.position = position
        self.right = right
        self.prob = cl_prob
        self.mse = mse
        self.ce = ce
        self.children = [self.left, self.right]
        self.level = level
        self.treelevel = treelevel
    
    def agregarHijo(self, children):

        if self.right is None:
            self.right = children
        elif self.left is None:
            self.left = children

        else:
            raise ValueError ("solo arbol binario ")


    def is_leaf(self):
        if self.right is None:
            return True
        else:
            return False

    def is_two_child(self):
        if self.right is not None and self.left is not None:
            return True
        else:
            return False

    def is_one_child(self):
        if self.is_two_child():
            return False
        elif self.is_leaf():
            return False
        else:
            return True

    def childs(self):
        if self.is_leaf():
            return 0
        if self.is_one_child():
            return 1
        else:
            return 2
    
    
    def traverseInorder(self, root):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorder(root.left)
            print (root.data, root.radius)
            self.traverseInorder(root.right)

    def traverseInorderwl(self, root):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderwl(root.left)
            print (root.data, root.radius, root.level, root.treelevel)
            self.traverseInorderwl(root.right)

    def get_tree_level(self, root, c):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.get_tree_level(root.left, c)
            c.append(root.level)
            self.get_tree_level(root.right, c)

    def set_tree_level(self, root, c):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.set_tree_level(root.left, c)
            root.treelevel = c
            self.set_tree_level(root.right, c)

    def traverseInorderLoss(self, root, loss):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderLoss(root.left, loss)
            loss.append(root.prob)
            self.traverseInorderLoss(root.right, loss)
            return loss

    def traverseInorderMSE(self, root, loss):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderMSE(root.left, loss)
            loss.append(root.mse)
            self.traverseInorderMSE(root.right, loss)
            return loss

    def traverseInorderCE(self, root, loss):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderCE(root.left, loss)
            loss.append(root.ce)
            self.traverseInorderCE(root.right, loss)
            return loss

    def traverseInorderChilds(self, root, l):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderChilds(root.left, l)
            l.append(root.childs())
            self.traverseInorderChilds(root.right, l)
            return l

    def preorder(self, root):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            print (root.data, root.radius)
            self.preorder(root.left)
            self.preorder(root.right)

    def cloneBinaryTree(self, root):
     
        # base case
        if root is None:
            return None
    
        # create a new node with the same data as the root node
        root_copy = Node(root.data, root.radius)
    
        # clone the left and right subtree
        root_copy.left = self.cloneBinaryTree(root.left)
        root_copy.right = self.cloneBinaryTree(root.right)
    
        # return cloned root node
        return root_copy

    def height(self, root):
    # Check if the binary tree is empty
        if root is None:
            return 0 
        # Recursively call height of each node
        leftAns = self.height(root.left)
        rightAns = self.height(root.right)
    
        # Return max(leftHeight, rightHeight) at each iteration
        return max(leftAns, rightAns) + 1

    # Print nodes at a current level
    def printCurrentLevel(self, root, level):
        if root is None:
            return
        if level == 1:
            print(root.data, end=" ")
        elif level > 1:
            self.printCurrentLevel(root.left, level-1)
            self.printCurrentLevel(root.right, level-1)

    def printLevelOrder(self, root):
        h = self.height(root)
        for i in range(1, h+1):
            self.printCurrentLevel(root, i)


    
    def count_nodes(self, root, counter):
        if   root is not None:
            self.count_nodes(root.left, counter)
            counter.append(root.data)
            self.count_nodes(root.right, counter)
            return counter

    
    def serialize(self, root):
        def post_order(root):
            if root:
                post_order(root.left)
                post_order(root.right)
                ret[0] += str(root.data)+'_'+ str(root.radius) +';'
                
            else:
                ret[0] += '#;'           

        ret = ['']
        post_order(root)
        return ret[0][:-1]  # remove last ,

    def toGraph( self, graph, index, dec, proc=True):
        
        
        radius = self.radius.cpu().detach().numpy()
        if dec:
            radius= radius[0]
        #print("posicion", self.data, radius)
        #print("right", self.right)
        
        #graph.add_nodes_from( [ (index, {'posicion': radius[0:3], 'radio': radius[3] } ) ])
        graph.add_nodes_from( [ (self.data, {'posicion': radius[0:3], 'radio': radius[3] } ) ])
        

        if self.right is not None:
            #leftIndex = self.right.toGraph( graph, index + 1, dec)#
            self.right.toGraph( graph, index + 1, dec)#
            
            #graph.add_edge( index, index + 1 )
            graph.add_edge( self.data, self.right.data )
            #if proc:
            #    nx.set_edge_attributes( graph, {(index, index+1) : {'procesada':False}})
        
            if self.left is not None:
                #retIndex = self.left.toGraph( graph, leftIndex, dec )#
                self.left.toGraph( graph, 0, dec )#

                #graph.add_edge( index, leftIndex)
                graph.add_edge( self.data, self.left.data)
                #if proc:
                #    nx.set_edge_attributes( graph, {(index, leftIndex) : {'procesada':False}})
            
            else:
                #return leftIndex
                return

        else:
            #return index + 1
            return

# %% [markdown]
# Funciones extra

# %%
use_gpu = True
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")

# %%
def plotTree( root, dec ):
    graph = nx.Graph()
    root.toGraph( graph, 0, dec)
    edges=nx.get_edge_attributes(graph,'procesada')

    p = mp.plot( np.array([ graph.nodes[v]['posicion'] for v in graph.nodes]), shading={'point_size':0.1}, return_plot=True)

    for arista in graph.edges:
        p.add_lines( graph.nodes[arista[0]]['posicion'], graph.nodes[arista[1]]['posicion'])

    return 

def traverse(root, tree):
       
        if root is not None:
            traverse(root.left, tree)
            tree.append((root.radius, root.data))
            traverse(root.right, tree)
            return tree

def traverse_2(tree1, tree2, t_l):
       
        if tree1 is not None:
            traverse_2(tree1.left, tree2.left, t_l)
            if tree2:
                t_l.append((tree1.radius, tree2.radius))
                print((tree1.radius, tree2.radius))
            else:
                t_l.append(tree1.radius)
                print((tree1.radius))
            traverse_2(tree1.right, tree2, t_l)
            return t_l
            

def traverse_conexiones(root, tree):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            traverse_conexiones(root.left, tree)
            if root.right is not None:
                tree.append((root.data, root.right.data))
            if root.left is not None:
                tree.append((root.data, root.left.data))
            traverse_conexiones(root.right, tree)
            return tree

def arbolAGrafo (nodoRaiz):
    
    conexiones = []
    lineas = traverse_conexiones(nodoRaiz, conexiones)
    tree = []
    tree = traverse(nodoRaiz, tree)

    vertices = []
    verticesCrudos = []
    for node in tree:
        vertice = node[0][0][:3]
        rad = node[0][0][-1]
        num = node[1]
        
        #vertices.append((num, {'posicion': Vec3( vertice[0], vertice[1], vertice[2]), 'radio': rad} ))
        vertices.append((len(verticesCrudos),{'posicion': Vec3( vertice[0], vertice[1], vertice[2]), 'radio': rad}))
        verticesCrudos.append(vertice)


    G = nx.Graph()
    G.add_nodes_from( vertices )
    G.add_edges_from( lineas )
    
    return G

@count_fn
def createNode(data, radius, position = None, left = None, right = None, cl_prob = None, ce = None, mse=None):
        """
        Utility function to create a node.
        """
        return Node(data, radius, position, left, right, cl_prob, ce, mse)
 
def deserialize(data):
    if  not data:
        return 
    nodes = data.split(';')  
    
    def post_order(nodes):
                
        if nodes[-1] == '#':
            nodes.pop()
            return None
        node = nodes.pop().split('_')
       
        data = int(node[0])
        
        #radius = float(node[1])
        #print("node", node)
        #breakpoint()
        radius = node[1]
        #print("radius", radius)
        rad = radius.split(",")

        rad [0] = rad[0].replace('[','')
        rad [4] = rad[4].replace(']','')
        r = []
        for value in rad:
            r.append(float(value))
        #r =[float(num) for num in radius if num.isdigit()]
        r = torch.tensor(r, device=device)
        #breakpoint()
        root = createNode(data, r)
        root.right = post_order(nodes)
        root.left = post_order(nodes)
        
        return root    
    return post_order(nodes)    


def read_tree(filename):
    with open('./trees/' +filename, "r") as f:
        byte = f.read() 
        return byte

# %% [markdown]
# Encoder

# %%
class InternalEncoder(nn.Module):
    
    def __init__(self, input_size: int, feature_size: int, hidden_size: int):
        super(InternalEncoder, self).__init__()

        #print("init")
        # Encoders atributos
        self.attribute_lin_encoder_1 = nn.Linear(input_size,hidden_size)
        self.attribute_lin_encoder_2 = nn.Linear(hidden_size,feature_size)

        # Encoders derecho e izquierdo
        self.right_lin_encoder_1 = nn.Linear(feature_size,feature_size)
        self.left_lin_encoder_1  = nn.Linear(feature_size,feature_size)

        # Encoder final
        self.final_lin_encoder_1 = nn.Linear(2*feature_size, feature_size)

        # Funciones / Parametros utiles
        self.tanh = nn.Tanh()
        self.feature_size = feature_size
        #print("fin")

    def forward(self, input, right_input, left_input):
        #print("estoy encodeando")
        #print("input", input.shape)
        input = input.reshape(-1,5)
        #print("input", input.shape)

        #print("right input", right_input)
        # Encodeo los atributos
        attributes = self.attribute_lin_encoder_1(input)
        attributes = self.tanh(attributes)
        attributes = self.attribute_lin_encoder_2(attributes)
        attributes = self.tanh(attributes)
        #print("attributes", attributes)

        # Encodeo el derecho
        if right_input is not None:
            #print("right input", right_input)
            context = self.right_lin_encoder_1(right_input)
            #print("context derecho", context)
            # Encodeo el izquierdo
            #print("left input", left_input)
            if left_input is not None:
                
                context += self.left_lin_encoder_1(left_input)
                #print("context izquierdo", context.shape)
        else:
            context = torch.zeros(input.shape[0],self.feature_size, requires_grad=True, device=device)
        

        context = self.tanh(context)
        #print("context shape", context.shape)
        #print("attributes shape", attributes.shape)
        #if len(attributes.shape) == 1:
            #print("len(attributes.shape)",len(attributes.shape))
            #attributes = attributes.reshape(1, 128)
        #print("attributes shape", attributes.shape)

        feature = torch.cat((attributes,context), 1)
        #print("feature cat", feature.shape)

        feature = self.final_lin_encoder_1(feature)
        feature = self.tanh(feature)
        #print("output", feature)
        return feature

        #print("radius", radius.shape)
        #if right_input is not None:
        #    context = self.right(right_input)
        #    #print("context", context.shape)
        #    if left_input is not None:
        #        context += self.left(left_input)
        #        #print("context2", context.shape)
        #    context = self.tanh(context)
        #    #print("context3", context.shape)
        #    feature = torch.cat((radius,context), 1)
        #    #print("feature", feature.shape)
        #    feature = self.encoder(feature)
        #else:
        #    feature = self.l3(radius)
        #    feature = self.tanh(feature)
        #    feature = self.leafencoder(radius)
        #    #print("feature", feature.shape)

        #feature = self.tanh(feature)
        #return feature
    

class GRASSEncoder(nn.Module):
    
    def __init__(self, input_size: int, feature_size : int, hidden_size: int):
        super(GRASSEncoder, self).__init__()
        self.leaf_encoder = InternalEncoder(input_size,feature_size, hidden_size)
        self.internal_encoder = InternalEncoder(input_size,feature_size, hidden_size)
        self.bifurcation_encoder = InternalEncoder(input_size,feature_size, hidden_size)
        
    def leafEncoder(self, node, right=None, left = None):
        return self.internal_encoder(node, right, left)
    def internalEncoder(self, node, right, left = None):
        return self.internal_encoder(node, right, left)
    def bifurcationEncoder(self, node, right, left):
        
        return self.bifurcation_encoder(node, right, left)

Grassencoder = GRASSEncoder(input_size = 5, feature_size=128, hidden_size=256)
Grassencoder = Grassencoder.to(device)


def encode_structure_fold(fold, root):
    
    
    def encode_node(node):
        
        if node is None:
            return
        
        if node.is_leaf():
            return fold.add('leafEncoder', node.radius)
        else:
            left = encode_node(node.left)
            right = encode_node(node.right)
            if left is not None:
             
                return fold.add('bifurcationEncoder', node.radius, right, left)
            else:
                return fold.add('internalEncoder', node.radius, right)
        

    encoding = encode_node(root)
    
    return encoding
  
def encode_structure(root):
    
    def encode_node(node):
          
        if node is None:
            return
        if node.is_leaf():
            return Grassencoder.leafEncoder(node.radius.reshape(-1,4))
        else :
            left = encode_node(node.left)
            right = encode_node(node.right)
            if left is not None:
                return Grassencoder.bifurcationEncoder(node.radius.reshape(-1,4), right, left)
            else:
                return Grassencoder.internalEncoder(node.radius.reshape(-1,4), right)
        

    encoding = encode_node(root)
   
    return encoding

# %% [markdown]
# Extra

# %%
def numerar_nodos(root, count):
    if root is not None:
        numerar_nodos(root.left, count)
        root.data = len(count)
        count.append(1)
        numerar_nodos(root.right, count)
        return 


def traversefeatures(root, features):
       
    if root is not None:
        traversefeatures(root.left, features)
        features.append(root.radius)
        traversefeatures(root.right, features)
        return features

def norm(root, minx, miny, minz, minr, minl, maxx, maxy, maxz, maxr, maxl):
    
    if root is not None:
        mx = minx.clone().detach()
        my = miny.clone().detach()
        mz = minz.clone().detach()
        mr = minr.clone().detach()
        ml = minl.clone().detach()
        Mx = maxx.clone().detach()
        My = maxy.clone().detach()
        Mz = maxz.clone().detach()
        Mr = maxr.clone().detach()
        Ml = maxl.clone().detach()
       
        root.radius[0] = (root.radius[0] - minx)/(maxx - minx)
        root.radius[1] = (root.radius[1] - miny)/(maxy - miny)
        root.radius[2] = (root.radius[2] - minz)/(maxz - minz)
        root.radius[3] = (root.radius[3] - minr)/(maxr - minr)
        root.radius[4] = (root.radius[4] - minl)/(maxl - minl)

        
        norm(root.left, mx, my, mz, mr, ml, Mx, My, Mz, Mr, Ml)
        norm(root.right, mx, my, mz, mr, ml, Mx, My, Mz, Mr, Ml)
        return 

def normalize_features(root):
    features = []
    features = traversefeatures(root, features)

    x = [tensor[0] for tensor in features]
    y = [tensor[1] for tensor in features]
    z = [tensor[2] for tensor in features]
    r = [tensor[3] for tensor in features]
    l = [tensor[4] for tensor in features]


 
    norm(root, min(x), min(y), min(z), min(r), min(l), max(x), max(y), max(z), max(r), max(l))

    return 

def traversefeatures(root, features):
       
    if root is not None:
        traversefeatures(root.left, features)
        features.append(root.radius)
        traversefeatures(root.right, features)
        return features

# %% [markdown]
# Dataloader

# %%
def my_collate(batch):
    return batch

#t_list = ['ArteryObjAN1-7.dat','ArteryObjAN1-0.dat', 'ArteryObjAN1-17.dat',  'ArteryObjAN1-11.dat']

#t_list = ['ArteryObjAN1-0.dat','ArteryObjAN1-7.dat', 'ArteryObjAN1-17.dat',  'ArteryObjAN1-11.dat', 'ArteryObjAN1-19.dat', 'ArteryObjAN2-4.dat', 'ArteryObjAN2-6.dat', 
#           'ArteryObjAN25-18.dat']
t_list = ['ArteryObjAN1-17-nl.dat']


#t_list = ['test2.dat']

#t_list = ['ArteryObjAN31-14.dat']
#t_list = os.listdir("./trees")[:20]
print(t_list)
class tDataset(Dataset):
    def __init__(self, dir, transform=None):
        self.names = dir
        self.transform = transform
        self.data = [] #lista con las strings de todos los arboles
        for file in self.names:
            self.data.append(read_tree(file))
        self.trees = []
        for tree in self.data:
            deserial = deserialize(tree)
            #normalize_features(deserial)
            self.trees.append(deserial)

    def __len__(self):
        return len(self.names)

    def __getitem__(self, idx):
        #file = self.names[idx]
        #string = read_tree(file)
        tree = self.trees[idx]
        return tree

batch_size = 1
dataset = tDataset(t_list)
data_loader = DataLoader(dataset, batch_size = batch_size, shuffle=True, collate_fn=my_collate)
# Out:
# ['ArteryObjAN1-17-nl.dat']

# %%
input = iter(data_loader).next()[0]
plotTree(input, False)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(13.846129…

# %%
n_no = []
qzero = 0
qOne = 0
qtwo = 0

for batch in data_loader:
    for tree in batch:
        count = []
        n = tree.count_nodes(tree, count)
        n_no.append(len(n))
        li = []
        tree.traverseInorderChilds(tree, li)
        zero = [a for a in li if a == 0]
        one = [a for a in li if a == 1]
        two = [a for a in li if a == 2]
        qzero += len(zero)
        qOne += len(one)
        qtwo += len(two)

print(len(data_loader)*batch_size)
print(n_no)
nprom = np.mean(n_no)
print(nprom)
qzero /= len(data_loader)*batch_size
qOne /= len(data_loader)*batch_size
qtwo /= len(data_loader)*batch_size

print(qzero)
print(qOne)
print(qtwo)
# Out:
# 1
# [70]
# 70.0
# 3.0
# 65.0
# 2.0

# %% [markdown]
# clasificador

# %%
class NodeClassifier(nn.Module):
    
    def __init__(self, latent_size : int, hidden_size : int):
        super(NodeClassifier, self).__init__()
        self.mlp1 = nn.Linear(latent_size, hidden_size)
        self.mlp2 = nn.Linear(hidden_size, hidden_size)
        self.mlp3 = nn.Linear(hidden_size, 3)
        self.tanh = nn.Tanh()

    def forward(self, input_feature):
        #print("classifier input", input_feature)
        output = self.mlp1(input_feature)
        output = self.tanh(output)
        output = self.mlp2(output)
        output = self.tanh(output)
        output = self.mlp3(output)
        #print("classifier output", output)

        return output

# %% [markdown]
# decoder

# %%
class Decoder(nn.Module):
    
    """ Decode an input (parent) feature into a left-child and a right-child feature """
    def __init__(self, latent_size : int, hidden_size : int):
        super(Decoder, self).__init__()
        #self.mlp = nn.Linear(latent_size,hidden_size)
        self.mlp = nn.Linear(latent_size,hidden_size)
        self.lp2 = nn.Linear(hidden_size, latent_size)
        self.mlp_left = nn.Linear(latent_size, latent_size)
        self.mlp_right = nn.Linear(latent_size, latent_size)
        self.mlp3 = nn.Linear(latent_size,latent_size)
        self.mlp2 = nn.Linear(latent_size,5)
        self.tanh = nn.Tanh()

    def common_branch(self, parent_feature):
        vector = self.mlp(parent_feature)
        vector = self.tanh(vector)
        vector = self.lp2(vector)
        vector = self.tanh(vector)
        return vector

    def attr_branch(self, vector):
        vector = self.mlp2(vector)        
        return vector

    def right_branch(self, vector):
        right_feature = self.mlp_right(vector)
        right_feature = self.tanh(right_feature)
        return right_feature

    def left_branch(self, vector):
        left_feature = self.mlp_left(vector)
        left_feature = self.tanh(left_feature)
        return left_feature

    def forward(self, parent_feature):
      
        vector      = self.common_branch(parent_feature)
        attr_vector = self.attr_branch(vector)
        return attr_vector 

    def forward1(self, parent_feature):
    

        vector       = self.common_branch(parent_feature)
        attr_vector  = self.attr_branch(vector)
        right_vector = self.right_branch(vector)
        
        #print("right vector", right_vector)
        #print("radius", attr_vector)
        return right_vector, attr_vector

    def forward2(self, parent_feature):
       

        vector       = self.common_branch(parent_feature)
        attr_vector  = self.attr_branch(vector)
        right_vector = self.right_branch(vector)
        left_vector  = self.left_branch(vector)
        #print("left vector", left_vector)
        #print("right vector", right_vector)
        #print("radius", attr_vector)
        return left_vector, right_vector, attr_vector



class GRASSDecoder(nn.Module):
    def __init__(self, latent_size : int, hidden_size: int, mult: torch.Tensor):
        super(GRASSDecoder, self).__init__()
        self.decoder = Decoder(latent_size, hidden_size)
        self.node_classifier = NodeClassifier(latent_size, hidden_size)
        self.mseLoss = nn.MSELoss()  # pytorch's mean squared error loss
        self.ceLoss = nn.CrossEntropyLoss(weight = mult)  # pytorch's cross entropy loss (NOTE: no softmax is needed before)
        


    def featureDecoder(self, feature):
        return self.decoder.forward(feature)

    def internalDecoder(self, feature):
        return self.decoder.forward1(feature)

    def bifurcationDecoder(self, feature):
        return self.decoder.forward2(feature)

    def nodeClassifier(self, feature):
        return self.node_classifier(feature)

    def calcularLossAtributo(self, nodo, radio):
        #print("nodo", nodo)
        #print("radio", radio)
        a, b = list(zip(*nodo))# a son los atributos, b los pesos
        if nodo is None:
            return
        else:
            nodo = torch.stack(list(a))
        
            l = [self.mseLoss(b.reshape(1,5), gt.reshape(1,5)) for b, gt in zip(radio.reshape(-1,5), nodo.reshape(-1,5))]
            #print("mse", l)
            return l


    def classifyLossEstimator(self, label_vector, original):
        if original is None:
            return
        else:
           
            v = []
            for o in original:
                if o == 0:
                    vector = torch.tensor([1, 0, 0], device=device, dtype = torch.float)
                if o == 1:
                    vector = torch.tensor([0, 1, 0], device=device, dtype = torch.float)
                if o == 2:
                    vector = torch.tensor([0, 0, 1], device=device, dtype = torch.float)
                v.append(vector)
            #print("////")
            #print("original", v)
            #print("prediction", label_vector)
            #print("////")

            v = torch.stack(v)
            #for b, gt in zip(label_vector.reshape(-1,3), v.reshape(-1,3)):
            #    print("...")
            #    print("b", b)
            #    print("gt", gt)
            #    print("...")
            l = [self.ceLoss(b.reshape(1,3), gt.reshape(1,3)).mul(0.4) for b, gt in zip(label_vector.reshape(-1,3), v.reshape(-1,3))]
            #print("ce", l)

            return l
            #return c
       # return torch.cat([self.creLoss(l.unsqueeze(0), gt).mul(0.2) for l, gt in zip(label_vector, gt_label_vector)], 0)

    
    def vectorAdder(self, v1, v2):
        v = v1.add(v2)
        return v

    def vectorMult(self, m, v):
        #print("v", v)
        #print("m", m)
        z = zip(v, m)
        r = []
        for c, d in z:
            #print("v", c)
            #print("m", d)
            r.append(torch.mul(c, d))
        #res = [torch.mul(v, m) for v, m in zip(v, m)]
        #print("res", r)
        return r

if round(qzero) == 0:
    qzero = 1
if round(qOne) == 0:
    qOne = 1
if round(qtwo) == 0:
    qtwo = 1

print("qs", qzero, qOne, qtwo)
mult = torch.tensor([1/round(qzero),1/round(qOne),1/round(qtwo)], device = device)

Grassdecoder = GRASSDecoder(latent_size=128, hidden_size=256, mult = mult)
Grassdecoder = Grassdecoder.to(device)
# Out:
# qs 3.0 65.0 2.0

# %%
def searchNode(node, key):
     
    if (node == None):
        return False
 
    if (node.data == key):
        return node
        
 
    """ then recur on left subtree """
    res1 = searchNode(node.left, key)
    # node found, no need to look further
    if res1:
        return res1
 
    """ node is not found in left,
    so recur on right subtree """
    res2 = searchNode(node.right, key)
    return res2

def getLevelUtil(node, data, level):
    if (node == None):
        return 0
 
    if (node.data == data):
        return level
 
    downlevel = getLevelUtil(node.left, data, level + 1)

    if (downlevel != 0):
        return downlevel
 
    downlevel = getLevelUtil(node.right, data, level + 1)
    return downlevel
 
# Returns level of given data value
 
 
def getLevel(node, data):
    return getLevelUtil(node, data, 1)
 

for d in data_loader:
    for data in d:
        print(data)
        count = []
        numerar_nodos(data, count)
        c = []
        n_nodes = data.count_nodes(data, c)
        for x in range(0, len(n_nodes)):
            level = getLevel(data, x)
            if (level):
                #print("Level of", x, "is", getLevel(input, x))
                node = searchNode(data, x)
                node.level = getLevel(data, x)
                #print("node radius", node.radius)
                #print("node radius", node.radius.reshape(1,4).shape)
                #print("node level", torch.tensor(float(node.level), requires_grad=True, device = device))
                #print("node level", torch.tensor(float(node.level), requires_grad=True, device = device).reshape(1,1).shape)
                #node.radius = torch.cat((node.radius.reshape(1,4), torch.tensor(float(node.level), requires_grad=True, device = device).reshape(1,1)),1).reshape(5)
                #print("node radius", node.radius.shape)

            else:
                print(x, "is not present in tree")
        tree_level = []
        data.get_tree_level(data, tree_level)
        print("tree level", sum(tree_level))
        data.set_tree_level(data, sum(tree_level))
        normalize_features(data)
# Out:
# <__main__.Node object at 0x0000019AB0F5A1D0>
# tree level 1185

# %%
for d in data_loader:
    for data in d:
        data.traverseInorder(data)
# Out:
# 0 tensor([0.5616, 0.4881, 0.2191, 0.2087, 1.0000], device='cuda:0')
# 1 tensor([0.5440, 0.4732, 0.2243, 0.2027, 1.0000], device='cuda:0')
# 2 tensor([0.5258, 0.4560, 0.2368, 0.1806, 1.0000], device='cuda:0')
# 3 tensor([0.5088, 0.4391, 0.2544, 0.1682, 1.0000], device='cuda:0')
# 4 tensor([0.4922, 0.4232, 0.2691, 0.1621, 1.0000], device='cuda:0')
# 5 tensor([0.4757, 0.4107, 0.2818, 0.1839, 1.0000], device='cuda:0')
# 6 tensor([0.4552, 0.3980, 0.2874, 0.2006, 1.0000], device='cuda:0')
# 7 tensor([0.4357, 0.3855, 0.2870, 0.2136, 1.0000], device='cuda:0')
# 8 tensor([0.4128, 0.3646, 0.3112, 0.2456, 1.0000], device='cuda:0')
# 9 tensor([0.3303, 0.3139, 0.3256, 0.3001, 1.0000], device='cuda:0')
# 10 tensor([0.3130, 0.3037, 0.3267, 0.2871, 1.0000], device='cuda:0')
# 11 tensor([0.2797, 0.2858, 0.3186, 0.3002, 1.0000], device='cuda:0')
# 12 tensor([0.2424, 0.2630, 0.3149, 0.3511, 1.0000], device='cuda:0')
# 13 tensor([0.1990, 0.2435, 0.2849, 0.3648, 1.0000], device='cuda:0')
# 14 tensor([0.1616, 0.2183, 0.2728, 0.3981, 1.0000], device='cuda:0')
# 15 tensor([0.0480, 0.1620, 0.2025, 0.1885, 0.5000], device='cuda:0')
# 16 tensor([0.0471, 0.1617, 0.1982, 0.1928, 0.5000], device='cuda:0')
# 17 tensor([0.0316, 0.1559, 0.1722, 0.1292, 0.5000], device='cuda:0')
# 18 tensor([0.0137, 0.1445, 0.1257, 0.1618, 0.5000], device='cuda:0')
# 19 tensor([0.0067, 0.1302, 0.0938, 0.1567, 0.5000], device='cuda:0')
# 20 tensor([0.0014, 0.1132, 0.0622, 0.1454, 0.5000], device='cuda:0')
# 21 tensor([0.0000, 0.1004, 0.0475, 0.1115, 0.5000], device='cuda:0')
# 22 tensor([0.0014, 0.0887, 0.0369, 0.0922, 0.5000], device='cuda:0')
# 23 tensor([0.0037, 0.0775, 0.0271, 0.0728, 0.5000], device='cuda:0')
# 24 tensor([0.0086, 0.0617, 0.0169, 0.0309, 0.5000], device='cuda:0')
# 25 tensor([0.0152, 0.0482, 0.0068, 0.0180, 0.5000], device='cuda:0')
# 26 tensor([0.0221, 0.0346, 0.0035, 0.0000, 0.5000], device='cuda:0')
# 27 tensor([0.0446, 0.0000, 0.0000, 0.0500, 0.5000], device='cuda:0')
# 28 tensor([0.1163, 0.1714, 0.2870, 1.0000, 0.0000], device='cuda:0')
# 29 tensor([0.1279, 0.1194, 0.3936, 0.1742, 0.0000], device='cuda:0')
# 30 tensor([0.1310, 0.1089, 0.4269, 0.1370, 0.0000], device='cuda:0')
# 31 tensor([0.1331, 0.0966, 0.4698, 0.1165, 0.0000], device='cuda:0')
# 32 tensor([0.1367, 0.0838, 0.5463, 0.1248, 0.0000], device='cuda:0')
# 33 tensor([0.1397, 0.0735, 0.6332, 0.1653, 0.0000], device='cuda:0')
# 34 tensor([0.1374, 0.0682, 0.7149, 0.1795, 0.0000], device='cuda:0')
# 35 tensor([0.1306, 0.0686, 0.7835, 0.1863, 0.0000], device='cuda:0')
# 36 tensor([0.1195, 0.0777, 0.8675, 0.2326, 0.0000], device='cuda:0')
# 37 tensor([0.1043, 0.0832, 0.9164, 0.2217, 0.0000], device='cuda:0')
# 38 tensor([0.0634, 0.1035, 1.0000, 0.3390, 0.0000], device='cuda:0')
# 39 tensor([0.5789, 0.5054, 0.2145, 0.1945, 1.0000], device='cuda:0')
# 40 tensor([0.5960, 0.5207, 0.2056, 0.1700, 1.0000], device='cuda:0')
# 41 tensor([0.6114, 0.5347, 0.1960, 0.1447, 1.0000], device='cuda:0')
# 42 tensor([0.6278, 0.5506, 0.1884, 0.1313, 1.0000], device='cuda:0')
# 43 tensor([0.6430, 0.5657, 0.1783, 0.1104, 1.0000], device='cuda:0')
# 44 tensor([0.6595, 0.5804, 0.1668, 0.1283, 1.0000], device='cuda:0')
# 45 tensor([0.6764, 0.5950, 0.1611, 0.1377, 1.0000], device='cuda:0')
# 46 tensor([0.6919, 0.6085, 0.1569, 0.1548, 1.0000], device='cuda:0')
# 47 tensor([0.7077, 0.6204, 0.1528, 0.1410, 1.0000], device='cuda:0')
# 48 tensor([0.7221, 0.6315, 0.1500, 0.1309, 1.0000], device='cuda:0')
# 49 tensor([0.7357, 0.6426, 0.1507, 0.1254, 1.0000], device='cuda:0')
# 50 tensor([0.7505, 0.6554, 0.1533, 0.1181, 1.0000], device='cuda:0')
# 51 tensor([0.7644, 0.6687, 0.1587, 0.1185, 1.0000], device='cuda:0')
# 52 tensor([0.7810, 0.6845, 0.1669, 0.1084, 1.0000], device='cuda:0')
# 53 tensor([0.8008, 0.7034, 0.1695, 0.0882, 1.0000], device='cuda:0')
# 54 tensor([0.8209, 0.7195, 0.1880, 0.0921, 1.0000], device='cuda:0')
# 55 tensor([0.8394, 0.7371, 0.2081, 0.1146, 1.0000], device='cuda:0')
# 56 tensor([0.8545, 0.7538, 0.2239, 0.1209, 1.0000], device='cuda:0')
# 57 tensor([0.8686, 0.7713, 0.2359, 0.1149, 1.0000], device='cuda:0')
# 58 tensor([0.8831, 0.7861, 0.2549, 0.1117, 1.0000], device='cuda:0')
# 59 tensor([0.9002, 0.8049, 0.2781, 0.1551, 1.0000], device='cuda:0')
# 60 tensor([0.9160, 0.8208, 0.2926, 0.1697, 1.0000], device='cuda:0')
# 61 tensor([0.9274, 0.8349, 0.3052, 0.1741, 1.0000], device='cuda:0')
# 62 tensor([0.9391, 0.8510, 0.3190, 0.1802, 1.0000], device='cuda:0')
# 63 tensor([0.9538, 0.8696, 0.3377, 0.1776, 1.0000], device='cuda:0')
# 64 tensor([0.9657, 0.8867, 0.3622, 0.1812, 1.0000], device='cuda:0')
# 65 tensor([0.9739, 0.9021, 0.3899, 0.1566, 1.0000], device='cuda:0')
# 66 tensor([0.9843, 0.9205, 0.4337, 0.1645, 1.0000], device='cuda:0')
# 67 tensor([0.9941, 0.9472, 0.4795, 0.1831, 1.0000], device='cuda:0')
# 68 tensor([1.0000, 0.9678, 0.5346, 0.1908, 1.0000], device='cuda:0')
# 69 tensor([0.9985, 1.0000, 0.6220, 0.2447, 1.0000], device='cuda:0')

# %%
def decode_structure_fold_grass(fold, v, root):
   
    def decode_node(fold, v, node):
        
        
        if node.childs() == 0 : 

            radio = fold.add('featureDecoder', v)
            lossAtributo = fold.add('calcularLossAtributo', node, radio)

            label = fold.add('nodeClassifier', v)
            
            lossEstructura = fold.add('classifyLossEstimator', label, node)  
            multipl = node.level/node.treelevel
            losse = fold.add('vectorMult', multipl, lossEstructura)
            
            loss =  fold.add('vectorAdder', losse, lossAtributo)       
            return loss

            
            
        elif node.childs() == 1 :
            right, radius = fold.add('internalDecoder', v).split(2)
            label = fold.add('nodeClassifier', v)
            nodoSiguiente = node.right
            if nodoSiguiente is not None:
                right_loss = decode_node(fold, right, nodoSiguiente)

            lossEstructura = fold.add('classifyLossEstimator', label, node)
            lossAtributo = fold.add('calcularLossAtributo', node, radius)
            multipl = node.level/node.treelevel
            losse = fold.add('vectorMult', multipl, lossEstructura)
            loss = fold.add('vectorAdder', losse, lossAtributo)
            
        
            loss2 = fold.add('vectorAdder', loss, right_loss)
            return loss2
            
            

        elif node.childs() == 2 :
            left, right, radius = fold.add('bifurcationDecoder', v).split(3)
            
            label = fold.add('nodeClassifier', v)            
            
            nodoSiguienteRight = node.right
            nodoSiguienteLeft = node.left


            if nodoSiguienteRight is not None:
                right_loss = decode_node(fold, right, nodoSiguienteRight)
             
            if nodoSiguienteLeft is not None:
                left_loss  = decode_node(fold, left, nodoSiguienteLeft)

            multipl = node.level/node.treelevel
            lossEstructura = fold.add('classifyLossEstimator', label, node)
            losse = fold.add('vectorMult', multipl, lossEstructura)
            lossAtributo   = fold.add('calcularLossAtributo', node, radius)
            loss = fold.add('vectorAdder', losse, lossAtributo)
            loss2 = fold.add('vectorAdder', loss, right_loss)
            loss3 = fold.add('vectorAdder', loss2, left_loss)
            
            return loss3
            

    dec = decode_node (fold, v, root)
    return dec

# %%
def decode_testing_grass(v, root, max, decoder):
    def decode_node(v, node, max, decoder):
        cl = decoder.nodeClassifier(v)
        _, label = torch.max(cl, 1)
        label = label.data
        
        
        if label == 0 and createNode.count <= max: ##output del classifier
           
            #lossEstructura = Grassdecoder.classifyLossEstimator(cl, node)
            radio = decoder.featureDecoder(v)
            #print("radius", radio)
            #lossAtrs = Grassdecoder.calcularLossAtributo( node, radio )
           
            return createNode(1,radio)

        elif label == 1 and createNode.count <= max:
       
            right, radius = decoder.internalDecoder(v)
            #print("radius", radius)
            
            d = createNode(1, radius) 
            #print("d", d.radius)
             
            if not node is None:
                if not node.right is None:
                    nodoSiguiente = node.right
                else:
                    nodoSiguiente = None
            else:
                nodoSiguiente = None
            
            d.right = decode_node(right, nodoSiguiente, max, decoder)
            

            return d
       
        elif label == 2 and createNode.count <= max:
            left, right, radius = decoder.bifurcationDecoder(v)
            #print("radius", radius)
            
            d = createNode(1, radius )
  
            if not node is None: #el nodo existe, me fijo si tiene hijo der/izq
                if not node.right is None:
                    nodoSiguienteRight = node.right
                else:
                    nodoSiguienteRight = None
                if not node.left is None:
                    nodoSiguienteLeft = node.left
                else:
                    nodoSiguienteLeft = None
            else: #el nodo no existe
                nodoSiguienteRight = None
                nodoSiguienteLeft = None
            
            d.right = decode_node(right, nodoSiguienteRight, max, decoder)
            d.left = decode_node(left, nodoSiguienteLeft, max, decoder)
            
           
            return d
            
    createNode.count = 0
    dec = decode_node (v, root, max, decoder)
    return dec

# %%
class SaveBestModel:
    """
    Class to save the best model while training. If the current epoch's 
    validation loss is less than the previous least less, then save the
    model state.
    """
    def __init__(
        self, best_valid_loss=float('inf')
    ):
        self.best_valid_loss = best_valid_loss
        
    def __call__(
        self, current_valid_loss, 
        epoch, encoder, decoder, optimizer
    ):
        if current_valid_loss < self.best_valid_loss:
            self.best_valid_loss = current_valid_loss
            #print(f"\nBest validation loss: {self.best_valid_loss}")
            #print(f"\nSaving best model for epoch: {epoch+1}\n")
            #'classifier_state_dict': classifier.state_dict(),
            torch.save({
                'epoch': epoch+1,
                'encoder_state_dict': encoder.state_dict(),
                'decoder_state_dict': decoder.state_dict(),
                
                'optimizer_state_dict': optimizer.state_dict(),
                }, 'outputs/best_model.pth')

save_best_model = SaveBestModel()

# %%
epochs = 8000
learning_rate = 1e-4
params = list(Grassencoder.parameters()) + list(Grassdecoder.parameters()) 

#opt = torch.optim.Adam(params, lr=learning_rate, weight_decay=0.0001) 
opt = torch.optim.Adam(params, lr=learning_rate) 
#opt = torch.optim.SGD(params, lr=learning_rate, momentum = 0.96) 

#scheduler = torch.optim.lr_scheduler.MultiStepLR(opt, milestones=[100], gamma=0.2)
import wandb
config = {
  "learning_rate": learning_rate,
  "epochs": epochs,
  "batch_size": batch_size,
  "dataset": t_list,
  "number of trees": len(data_loader)*batch_size,
  "optim": opt
}
wandb.init(project="autoencoder3", entity="paufeldman", config = config)
# Out:
# Finishing last run (ID:36t9vgpb) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▅▄▂▂▂▂▂▂▂▂▂▂▂▁▁▂▄▄▄▂▂▂▂▁▂▂▁▁▁▁▁▁▁▁▁▅▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>2678</td></tr><tr><td>loss</td><td>0.01284</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vital-leaf-209</strong>: <a href="https://wandb.ai/paufeldman/autoencoder3/runs/36t9vgpb" target="_blank">https://wandb.ai/paufeldman/autoencoder3/runs/36t9vgpb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221123_172138-36t9vgpb\logs</code>
# Successfully finished last run (ID:36t9vgpb). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016916666666899498, max=1.0…
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>c:\Users\User\Documents\rpoditela\Intra\autoencoder\wandb\run-20221123_172744-3nf357hm</code>
# Syncing run <strong><a href="https://wandb.ai/paufeldman/autoencoder3/runs/3nf357hm" target="_blank">glamorous-dew-210</a></strong> to <a href="https://wandb.ai/paufeldman/autoencoder3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/paufeldman/autoencoder3/runs/3nf357hm?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
train_loss_avg = []

ce_avg = []
mse_avg = []
lr_list = []
    
for epoch in range(epochs):
    train_loss_avg.append(0)
   #batch es cada arbol del dataloader
    for batch_idx, batch in enumerate(data_loader):
        # Initialize torchfold for *encoding*

        
        enc_fold = torch_f.Fold(device)
        enc_fold_nodes = []     # list of fold nodes for encoding, lista con la "hoja de ruta" de los dos arboles
        # Collect computation nodes recursively from encoding process
        n_nodes = []
        for example in batch: #example es un arbolito
            c = []
            n = example.count_nodes(example, c)
            n_nodes.append(len(n))
            encode_structure_fold(enc_fold, example)
            enc_fold_nodes.append(encode_structure_fold(enc_fold, example))
       
        # Apply the computations on the encoder model
       
        enc_fold_nodes = enc_fold.apply(Grassencoder, [enc_fold_nodes])
        
        
        # Initialize torchfold for *decoding*
        dec_fold = torch_f.Fold(device)
        # Collect computation nodes recursively from decoding process
        dec_fold_nodes = []
        kld_fold_nodes = []

        t_l = []
        for f in enc_fold_nodes:
            for t in f:
                t_l.append(t)
        for example, fnode in zip(batch, t_l): #example es el arbol y fnode el encodeado
            #print("example", example)
            #print("fnode", fnode) 
            #root_code, kl_div = torch.chunk(fnode, 2, 0)
            dec_fold_nodes.append(decode_structure_fold_grass(dec_fold, fnode, example))
        # Apply the computations on the decoder model

                       
        total_loss = dec_fold.apply(Grassdecoder, [dec_fold_nodes])#[0]
        #print("total_loss", total_loss)
        n_nodes = torch.tensor(n_nodes, device = device)
        #print("n", n_nodes)
        total_loss = torch.div(total_loss[0], n_nodes)
        #print("div", total_loss)
        total_loss = total_loss.sum() / len(batch)  #n_nodes[0] #modificar y dividir por el promedio?
        total_loss = total_loss#*10
        
        #print("total_loss", total_loss)
        
        
        opt.zero_grad()
        total_loss.backward(retain_graph=True)
        opt.step()
        #scheduler.step()
        train_loss_avg[-1] += (total_loss.item())
        

    wandb.log({'epoch': epoch+1, 'loss': total_loss})
    save_best_model(
        total_loss, epoch, Grassencoder, Grassdecoder, opt)
    if epoch % 10 == 0:
        print('Epoch [%d / %d] average reconstruction error: %.8f ' % (epoch+1, epochs, total_loss))
# Out:
# Epoch [1 / 8000] average reconstruction error: 0.31160367
# Epoch [11 / 8000] average reconstruction error: 0.25192198
# Epoch [21 / 8000] average reconstruction error: 0.19347693
# Epoch [31 / 8000] average reconstruction error: 0.12784065
# Epoch [41 / 8000] average reconstruction error: 0.08198271
# Epoch [51 / 8000] average reconstruction error: 0.08154106
# Epoch [61 / 8000] average reconstruction error: 0.08205207
# Epoch [71 / 8000] average reconstruction error: 0.08004550
# Epoch [81 / 8000] average reconstruction error: 0.07998826
# Epoch [91 / 8000] average reconstruction error: 0.07972528
# Epoch [101 / 8000] average reconstruction error: 0.07945711
# Epoch [111 / 8000] average reconstruction error: 0.07925887
# Epoch [121 / 8000] average reconstruction error: 0.07906394
# Epoch [131 / 8000] average reconstruction error: 0.07884279
# Epoch [141 / 8000] average reconstruction error: 0.07860196
# Epoch [151 / 8000] average reconstruction error: 0.07832864
# Epoch [161 / 8000] average reconstruction error: 0.07798847
# Epoch [171 / 8000] average reconstruction error: 0.07755648
# Epoch [181 / 8000] average reconstruction error: 0.07694749
# Epoch [191 / 8000] average reconstruction error: 0.07598618
# Epoch [201 / 8000] average reconstruction error: 0.07411437
# Epoch [211 / 8000] average reconstruction error: 0.06850474
# Epoch [221 / 8000] average reconstruction error: 0.06242996
# Epoch [231 / 8000] average reconstruction error: 0.06880362
# Epoch [241 / 8000] average reconstruction error: 0.07397694
# Epoch [251 / 8000] average reconstruction error: 0.07058734
# Epoch [261 / 8000] average reconstruction error: 0.06245352
# Epoch [271 / 8000] average reconstruction error: 0.04060922
# Epoch [281 / 8000] average reconstruction error: 0.05692122
# Epoch [291 / 8000] average reconstruction error: 0.03547147
# Epoch [301 / 8000] average reconstruction error: 0.03063908
# Epoch [311 / 8000] average reconstruction error: 0.02421347
# Epoch [321 / 8000] average reconstruction error: 0.02315310
# Epoch [331 / 8000] average reconstruction error: 0.02287872
# Epoch [341 / 8000] average reconstruction error: 0.02257685
# Epoch [351 / 8000] average reconstruction error: 0.02245550
# Epoch [361 / 8000] average reconstruction error: 0.02232680
# Epoch [371 / 8000] average reconstruction error: 0.02222371
# Epoch [381 / 8000] average reconstruction error: 0.02212983
# Epoch [391 / 8000] average reconstruction error: 0.02204355
# Epoch [401 / 8000] average reconstruction error: 0.02195638
# Epoch [411 / 8000] average reconstruction error: 0.02186752
# Epoch [421 / 8000] average reconstruction error: 0.02177996
# Epoch [431 / 8000] average reconstruction error: 0.02169413
# Epoch [441 / 8000] average reconstruction error: 0.02160592
# Epoch [451 / 8000] average reconstruction error: 0.02151727
# Epoch [461 / 8000] average reconstruction error: 0.02142751
# Epoch [471 / 8000] average reconstruction error: 0.02134291
# Epoch [481 / 8000] average reconstruction error: 0.02125125
# Epoch [491 / 8000] average reconstruction error: 0.02116434
# Epoch [501 / 8000] average reconstruction error: 0.02107259
# Epoch [511 / 8000] average reconstruction error: 0.02098582
# Epoch [521 / 8000] average reconstruction error: 0.02090051
# Epoch [531 / 8000] average reconstruction error: 0.02081049
# Epoch [541 / 8000] average reconstruction error: 0.02072242
# Epoch [551 / 8000] average reconstruction error: 0.02063734
# Epoch [561 / 8000] average reconstruction error: 0.02055110
# Epoch [571 / 8000] average reconstruction error: 0.02046260
# Epoch [581 / 8000] average reconstruction error: 0.02037803
# Epoch [591 / 8000] average reconstruction error: 0.02029380
# Epoch [601 / 8000] average reconstruction error: 0.02020518
# Epoch [611 / 8000] average reconstruction error: 0.02011984
# Epoch [621 / 8000] average reconstruction error: 0.02003282
# Epoch [631 / 8000] average reconstruction error: 0.01999204
# Epoch [641 / 8000] average reconstruction error: 0.02001776
# Epoch [651 / 8000] average reconstruction error: 0.01978262
# Epoch [661 / 8000] average reconstruction error: 0.02783608
# Epoch [671 / 8000] average reconstruction error: 0.02336914
# Epoch [681 / 8000] average reconstruction error: 0.02326017
# Epoch [691 / 8000] average reconstruction error: 0.02014439
# Epoch [701 / 8000] average reconstruction error: 0.01984364
# Epoch [711 / 8000] average reconstruction error: 0.01973489
# Epoch [721 / 8000] average reconstruction error: 0.01950447
# Epoch [731 / 8000] average reconstruction error: 0.01940621
# Epoch [741 / 8000] average reconstruction error: 0.01931503
# Epoch [751 / 8000] average reconstruction error: 0.01922442
# Epoch [761 / 8000] average reconstruction error: 0.01914171
# Epoch [771 / 8000] average reconstruction error: 0.01905753
# Epoch [781 / 8000] average reconstruction error: 0.01897257
# Epoch [791 / 8000] average reconstruction error: 0.01889346
# Epoch [801 / 8000] average reconstruction error: 0.01882526
# Epoch [811 / 8000] average reconstruction error: 0.01913134
# Epoch [821 / 8000] average reconstruction error: 0.02767669
# Epoch [831 / 8000] average reconstruction error: 0.02657474
# Epoch [841 / 8000] average reconstruction error: 0.02043427
# Epoch [851 / 8000] average reconstruction error: 0.03018031
# Epoch [861 / 8000] average reconstruction error: 0.02417212
# Epoch [871 / 8000] average reconstruction error: 0.02068110
# Epoch [881 / 8000] average reconstruction error: 0.01885692
# Epoch [891 / 8000] average reconstruction error: 0.01879711
# Epoch [901 / 8000] average reconstruction error: 0.01855068
# Epoch [911 / 8000] average reconstruction error: 0.01841681
# Epoch [921 / 8000] average reconstruction error: 0.01830383
# Epoch [931 / 8000] average reconstruction error: 0.01818996
# Epoch [941 / 8000] average reconstruction error: 0.01806828
# Epoch [951 / 8000] average reconstruction error: 0.01793755
# Epoch [961 / 8000] average reconstruction error: 0.01779202
# Epoch [971 / 8000] average reconstruction error: 0.01763124
# Epoch [981 / 8000] average reconstruction error: 0.01743682
# Epoch [991 / 8000] average reconstruction error: 0.01720133
# Epoch [1001 / 8000] average reconstruction error: 0.01689495
# Epoch [1011 / 8000] average reconstruction error: 0.01644752
# Epoch [1021 / 8000] average reconstruction error: 0.01568620
# Epoch [1031 / 8000] average reconstruction error: 0.01405557
# Epoch [1041 / 8000] average reconstruction error: 0.02271030
# Epoch [1051 / 8000] average reconstruction error: 0.01473130
# Epoch [1061 / 8000] average reconstruction error: 0.01307861
# Epoch [1071 / 8000] average reconstruction error: 0.01548878
# Epoch [1081 / 8000] average reconstruction error: 0.01229449
# Epoch [1091 / 8000] average reconstruction error: 0.01003935
# Epoch [1101 / 8000] average reconstruction error: 0.00853085
# Epoch [1111 / 8000] average reconstruction error: 0.00764045
# Epoch [1121 / 8000] average reconstruction error: 0.00928178
# Epoch [1131 / 8000] average reconstruction error: 0.04155224
# Epoch [1141 / 8000] average reconstruction error: 0.02933893
# Epoch [1151 / 8000] average reconstruction error: 0.02091963
# Epoch [1161 / 8000] average reconstruction error: 0.02021494
# Epoch [1171 / 8000] average reconstruction error: 0.01754585
# Epoch [1181 / 8000] average reconstruction error: 0.01761515
# Epoch [1191 / 8000] average reconstruction error: 0.01610690
# Epoch [1201 / 8000] average reconstruction error: 0.01480831
# Epoch [1211 / 8000] average reconstruction error: 0.01343125
# Epoch [1221 / 8000] average reconstruction error: 0.06854907
# Epoch [1231 / 8000] average reconstruction error: 0.08872514
# Epoch [1241 / 8000] average reconstruction error: 0.07542980
# Epoch [1251 / 8000] average reconstruction error: 0.07348084
# Epoch [1261 / 8000] average reconstruction error: 0.06468849
# Epoch [1271 / 8000] average reconstruction error: 0.06179923
# Epoch [1281 / 8000] average reconstruction error: 0.05972588
# Epoch [1291 / 8000] average reconstruction error: 0.05869675
# Epoch [1301 / 8000] average reconstruction error: 0.05809485
# Epoch [1311 / 8000] average reconstruction error: 0.05756109
# Epoch [1321 / 8000] average reconstruction error: 0.05706565
# Epoch [1331 / 8000] average reconstruction error: 0.05652027
# Epoch [1341 / 8000] average reconstruction error: 0.05587997
# Epoch [1351 / 8000] average reconstruction error: 0.05509747
# Epoch [1361 / 8000] average reconstruction error: 0.05401734
# Epoch [1371 / 8000] average reconstruction error: 0.05232678
# Epoch [1381 / 8000] average reconstruction error: 0.04917355
# Epoch [1391 / 8000] average reconstruction error: 0.04443017
# Epoch [1401 / 8000] average reconstruction error: 0.06047157
# Epoch [1411 / 8000] average reconstruction error: 0.03831085
# Epoch [1421 / 8000] average reconstruction error: 0.03462536
# Epoch [1431 / 8000] average reconstruction error: 0.03191265
# Epoch [1441 / 8000] average reconstruction error: 0.03003356
# Epoch [1451 / 8000] average reconstruction error: 0.02796816
# Epoch [1461 / 8000] average reconstruction error: 0.02710914
# Epoch [1471 / 8000] average reconstruction error: 0.02644552
# Epoch [1481 / 8000] average reconstruction error: 0.02577363
# Epoch [1491 / 8000] average reconstruction error: 0.02519166
# Epoch [1501 / 8000] average reconstruction error: 0.02487558
# Epoch [1511 / 8000] average reconstruction error: 0.02460724
# Epoch [1521 / 8000] average reconstruction error: 0.02439363
# Epoch [1531 / 8000] average reconstruction error: 0.02418919
# Epoch [1541 / 8000] average reconstruction error: 0.02398114
# Epoch [1551 / 8000] average reconstruction error: 0.02375889
# Epoch [1561 / 8000] average reconstruction error: 0.02354441
# Epoch [1571 / 8000] average reconstruction error: 0.02329314
# Epoch [1581 / 8000] average reconstruction error: 0.02301950
# Epoch [1591 / 8000] average reconstruction error: 0.02270307
# Epoch [1601 / 8000] average reconstruction error: 0.02236014
# Epoch [1611 / 8000] average reconstruction error: 0.02196455
# Epoch [1621 / 8000] average reconstruction error: 0.02152714
# Epoch [1631 / 8000] average reconstruction error: 0.02105328
# Epoch [1641 / 8000] average reconstruction error: 0.02053854
# Epoch [1651 / 8000] average reconstruction error: 0.01996056
# Epoch [1661 / 8000] average reconstruction error: 0.01927830
# Epoch [1671 / 8000] average reconstruction error: 0.01841729
# Epoch [1681 / 8000] average reconstruction error: 0.01732527
# Epoch [1691 / 8000] average reconstruction error: 0.01573663
# Epoch [1701 / 8000] average reconstruction error: 0.01333592
# Epoch [1711 / 8000] average reconstruction error: 0.00953162
# Epoch [1721 / 8000] average reconstruction error: 0.06714318
# Epoch [1731 / 8000] average reconstruction error: 0.04405746
# Epoch [1741 / 8000] average reconstruction error: 0.03104340
# Epoch [1751 / 8000] average reconstruction error: 0.02880471
# Epoch [1761 / 8000] average reconstruction error: 0.02627083
# Epoch [1771 / 8000] average reconstruction error: 0.02459709
# Epoch [1781 / 8000] average reconstruction error: 0.02338086
# Epoch [1791 / 8000] average reconstruction error: 0.02224071
# Epoch [1801 / 8000] average reconstruction error: 0.02106401
# Epoch [1811 / 8000] average reconstruction error: 0.01994905
# Epoch [1821 / 8000] average reconstruction error: 0.01896459
# Epoch [1831 / 8000] average reconstruction error: 0.01814212
# Epoch [1841 / 8000] average reconstruction error: 0.01744917
# Epoch [1851 / 8000] average reconstruction error: 0.01682663
# Epoch [1861 / 8000] average reconstruction error: 0.01623241
# Epoch [1871 / 8000] average reconstruction error: 0.01564742
# Epoch [1881 / 8000] average reconstruction error: 0.01505625
# Epoch [1891 / 8000] average reconstruction error: 0.01445302
# Epoch [1901 / 8000] average reconstruction error: 0.01385317
# Epoch [1911 / 8000] average reconstruction error: 0.01325178
# Epoch [1921 / 8000] average reconstruction error: 0.01266052
# Epoch [1931 / 8000] average reconstruction error: 0.01210287
# Epoch [1941 / 8000] average reconstruction error: 0.01159980
# Epoch [1951 / 8000] average reconstruction error: 0.01116921
# Epoch [1961 / 8000] average reconstruction error: 0.01079957
# Epoch [1971 / 8000] average reconstruction error: 0.01048790
# Epoch [1981 / 8000] average reconstruction error: 0.01021818
# Epoch [1991 / 8000] average reconstruction error: 0.00998011
# Epoch [2001 / 8000] average reconstruction error: 0.00977207
# Epoch [2011 / 8000] average reconstruction error: 0.00958672
# Epoch [2021 / 8000] average reconstruction error: 0.00941922
# Epoch [2031 / 8000] average reconstruction error: 0.00926986
# Epoch [2041 / 8000] average reconstruction error: 0.00913245
# Epoch [2051 / 8000] average reconstruction error: 0.00900590
# Epoch [2061 / 8000] average reconstruction error: 0.00889018
# Epoch [2071 / 8000] average reconstruction error: 0.00878273
# Epoch [2081 / 8000] average reconstruction error: 0.00870352
# Epoch [2091 / 8000] average reconstruction error: 0.00874569
# Epoch [2101 / 8000] average reconstruction error: 0.00894098
# Epoch [2111 / 8000] average reconstruction error: 0.00862716
# Epoch [2121 / 8000] average reconstruction error: 0.00859249
# Epoch [2131 / 8000] average reconstruction error: 0.00841167
# Epoch [2141 / 8000] average reconstruction error: 0.00826163
# Epoch [2151 / 8000] average reconstruction error: 0.00816458
# Epoch [2161 / 8000] average reconstruction error: 0.00830603
# Epoch [2171 / 8000] average reconstruction error: 0.00833080
# Epoch [2181 / 8000] average reconstruction error: 0.00836071
# Epoch [2191 / 8000] average reconstruction error: 0.01264246
# Epoch [2201 / 8000] average reconstruction error: 0.02409199
# Epoch [2211 / 8000] average reconstruction error: 0.02295569
# Epoch [2221 / 8000] average reconstruction error: 0.01390338
# Epoch [2231 / 8000] average reconstruction error: 0.01127609
# Epoch [2241 / 8000] average reconstruction error: 0.00987381
# Epoch [2251 / 8000] average reconstruction error: 0.00911264
# Epoch [2261 / 8000] average reconstruction error: 0.00872590
# Epoch [2271 / 8000] average reconstruction error: 0.00842819
# Epoch [2281 / 8000] average reconstruction error: 0.00820962
# Epoch [2291 / 8000] average reconstruction error: 0.00804649
# Epoch [2301 / 8000] average reconstruction error: 0.00791643
# Epoch [2311 / 8000] average reconstruction error: 0.00782013
# Epoch [2321 / 8000] average reconstruction error: 0.00773043
# Epoch [2331 / 8000] average reconstruction error: 0.00766137
# Epoch [2341 / 8000] average reconstruction error: 0.00760438
# Epoch [2351 / 8000] average reconstruction error: 0.00755606
# Epoch [2361 / 8000] average reconstruction error: 0.00751921
# Epoch [2371 / 8000] average reconstruction error: 0.00747214
# Epoch [2381 / 8000] average reconstruction error: 0.00743567
# Epoch [2391 / 8000] average reconstruction error: 0.00740085
# Epoch [2401 / 8000] average reconstruction error: 0.00736824
# Epoch [2411 / 8000] average reconstruction error: 0.00733453
# Epoch [2421 / 8000] average reconstruction error: 0.00745239
# Epoch [2431 / 8000] average reconstruction error: 0.00744572
# Epoch [2441 / 8000] average reconstruction error: 0.00728079
# Epoch [2451 / 8000] average reconstruction error: 0.00723360
# Epoch [2461 / 8000] average reconstruction error: 0.00732856
# Epoch [2471 / 8000] average reconstruction error: 0.00731743
# Epoch [2481 / 8000] average reconstruction error: 0.00750457
# Epoch [2491 / 8000] average reconstruction error: 0.08527218
# Epoch [2501 / 8000] average reconstruction error: 0.05063806
# Epoch [2511 / 8000] average reconstruction error: 0.04192997
# Epoch [2521 / 8000] average reconstruction error: 0.03243297
# Epoch [2531 / 8000] average reconstruction error: 0.02967537
# Epoch [2541 / 8000] average reconstruction error: 0.02764314
# Epoch [2551 / 8000] average reconstruction error: 0.02851788
# Epoch [2561 / 8000] average reconstruction error: 0.02581530
# Epoch [2571 / 8000] average reconstruction error: 0.02577985
# Epoch [2581 / 8000] average reconstruction error: 0.02439575
# Epoch [2591 / 8000] average reconstruction error: 0.02339979
# Epoch [2601 / 8000] average reconstruction error: 0.02272053
# Epoch [2611 / 8000] average reconstruction error: 0.02193758
# Epoch [2621 / 8000] average reconstruction error: 0.02107762
# Epoch [2631 / 8000] average reconstruction error: 0.02012284
# Epoch [2641 / 8000] average reconstruction error: 0.01902163
# Epoch [2651 / 8000] average reconstruction error: 0.01773245
# Epoch [2661 / 8000] average reconstruction error: 0.01616964
# Epoch [2671 / 8000] average reconstruction error: 0.01428794
# Epoch [2681 / 8000] average reconstruction error: 0.01224537
# Epoch [2691 / 8000] average reconstruction error: 0.01056709
# Epoch [2701 / 8000] average reconstruction error: 0.01602216
# Epoch [2711 / 8000] average reconstruction error: 0.01739276
# Epoch [2721 / 8000] average reconstruction error: 0.01179320
# Epoch [2731 / 8000] average reconstruction error: 0.01049263
# Epoch [2741 / 8000] average reconstruction error: 0.00968640
# Epoch [2751 / 8000] average reconstruction error: 0.00919933
# Epoch [2761 / 8000] average reconstruction error: 0.00879162
# Epoch [2771 / 8000] average reconstruction error: 0.00852048
# Epoch [2781 / 8000] average reconstruction error: 0.00832434
# Epoch [2791 / 8000] average reconstruction error: 0.00816628
# Epoch [2801 / 8000] average reconstruction error: 0.00802259
# Epoch [2811 / 8000] average reconstruction error: 0.00791947
# Epoch [2821 / 8000] average reconstruction error: 0.00788208
# Epoch [2831 / 8000] average reconstruction error: 0.00803445
# Epoch [2841 / 8000] average reconstruction error: 0.00755434
# Epoch [2851 / 8000] average reconstruction error: 0.00819094
# Epoch [2861 / 8000] average reconstruction error: 0.00741544
# Epoch [2871 / 8000] average reconstruction error: 0.00827778
# Epoch [2881 / 8000] average reconstruction error: 0.00754903
# Epoch [2891 / 8000] average reconstruction error: 0.00724815
# Epoch [2901 / 8000] average reconstruction error: 0.00710418
# Epoch [2911 / 8000] average reconstruction error: 0.00700256
# Epoch [2921 / 8000] average reconstruction error: 0.00689795
# Epoch [2931 / 8000] average reconstruction error: 0.00691822
# Epoch [2941 / 8000] average reconstruction error: 0.00684912
# Epoch [2951 / 8000] average reconstruction error: 0.00672003
# Epoch [2961 / 8000] average reconstruction error: 0.00669307
# Epoch [2971 / 8000] average reconstruction error: 0.00662844
# Epoch [2981 / 8000] average reconstruction error: 0.00689984
# Epoch [2991 / 8000] average reconstruction error: 0.00643165
# Epoch [3001 / 8000] average reconstruction error: 0.00645983
# Epoch [3011 / 8000] average reconstruction error: 0.00630961
# Epoch [3021 / 8000] average reconstruction error: 0.00631730
# Epoch [3031 / 8000] average reconstruction error: 0.00622301
# Epoch [3041 / 8000] average reconstruction error: 0.00617989
# Epoch [3051 / 8000] average reconstruction error: 0.00618253
# Epoch [3061 / 8000] average reconstruction error: 0.00627494
# Epoch [3071 / 8000] average reconstruction error: 0.00608324
# Epoch [3081 / 8000] average reconstruction error: 0.00606511
# Epoch [3091 / 8000] average reconstruction error: 0.00591031
# Epoch [3101 / 8000] average reconstruction error: 0.00591075
# Epoch [3111 / 8000] average reconstruction error: 0.00701050
# Epoch [3121 / 8000] average reconstruction error: 0.00618766
# Epoch [3131 / 8000] average reconstruction error: 0.00583765
# Epoch [3141 / 8000] average reconstruction error: 0.00577647
# Epoch [3151 / 8000] average reconstruction error: 0.00569024
# Epoch [3161 / 8000] average reconstruction error: 0.00563176
# Epoch [3171 / 8000] average reconstruction error: 0.00558408
# Epoch [3181 / 8000] average reconstruction error: 0.00553936
# Epoch [3191 / 8000] average reconstruction error: 0.00550332
# Epoch [3201 / 8000] average reconstruction error: 0.00545636
# Epoch [3211 / 8000] average reconstruction error: 0.00551910
# Epoch [3221 / 8000] average reconstruction error: 0.00553127
# Epoch [3231 / 8000] average reconstruction error: 0.00557473
# Epoch [3241 / 8000] average reconstruction error: 0.00538946
# Epoch [3251 / 8000] average reconstruction error: 0.00531224
# Epoch [3261 / 8000] average reconstruction error: 0.00527721
# Epoch [3271 / 8000] average reconstruction error: 0.00525802
# Epoch [3281 / 8000] average reconstruction error: 0.00520692
# Epoch [3291 / 8000] average reconstruction error: 0.00516363
# Epoch [3301 / 8000] average reconstruction error: 0.00518203
# Epoch [3311 / 8000] average reconstruction error: 0.00697525
# Epoch [3321 / 8000] average reconstruction error: 0.00603204
# Epoch [3331 / 8000] average reconstruction error: 0.00544929
# Epoch [3341 / 8000] average reconstruction error: 0.00524296
# Epoch [3351 / 8000] average reconstruction error: 0.00511449
# Epoch [3361 / 8000] average reconstruction error: 0.00503786
# Epoch [3371 / 8000] average reconstruction error: 0.00499679
# Epoch [3381 / 8000] average reconstruction error: 0.00496401
# Epoch [3391 / 8000] average reconstruction error: 0.00493170
# Epoch [3401 / 8000] average reconstruction error: 0.00490298
# Epoch [3411 / 8000] average reconstruction error: 0.00487483
# Epoch [3421 / 8000] average reconstruction error: 0.00484847
# Epoch [3431 / 8000] average reconstruction error: 0.00482363
# Epoch [3441 / 8000] average reconstruction error: 0.00485313
# Epoch [3451 / 8000] average reconstruction error: 0.00503314
# Epoch [3461 / 8000] average reconstruction error: 0.00489352
# Epoch [3471 / 8000] average reconstruction error: 0.00483468
# Epoch [3481 / 8000] average reconstruction error: 0.00475567
# Epoch [3491 / 8000] average reconstruction error: 0.00471150
# Epoch [3501 / 8000] average reconstruction error: 0.00470893
# Epoch [3511 / 8000] average reconstruction error: 0.00475824
# Epoch [3521 / 8000] average reconstruction error: 0.00469071
# Epoch [3531 / 8000] average reconstruction error: 0.00463528
# Epoch [3541 / 8000] average reconstruction error: 0.00471683
# Epoch [3551 / 8000] average reconstruction error: 0.00460742
# Epoch [3561 / 8000] average reconstruction error: 0.00485996
# Epoch [3571 / 8000] average reconstruction error: 0.00472125
# Epoch [3581 / 8000] average reconstruction error: 0.00457004
# Epoch [3591 / 8000] average reconstruction error: 0.00563765
# Epoch [3601 / 8000] average reconstruction error: 0.00454493
# Epoch [3611 / 8000] average reconstruction error: 0.00454710
# Epoch [3621 / 8000] average reconstruction error: 0.00452556
# Epoch [3631 / 8000] average reconstruction error: 0.00460058
# Epoch [3641 / 8000] average reconstruction error: 0.00447814
# Epoch [3651 / 8000] average reconstruction error: 0.00474097
# Epoch [3661 / 8000] average reconstruction error: 0.00449768
# Epoch [3671 / 8000] average reconstruction error: 0.00443783
# Epoch [3681 / 8000] average reconstruction error: 0.00466894
# Epoch [3691 / 8000] average reconstruction error: 0.00441080
# Epoch [3701 / 8000] average reconstruction error: 0.00443966
# Epoch [3711 / 8000] average reconstruction error: 0.00511927
# Epoch [3721 / 8000] average reconstruction error: 0.00481473
# Epoch [3731 / 8000] average reconstruction error: 0.00442065
# Epoch [3741 / 8000] average reconstruction error: 0.00481342
# Epoch [3751 / 8000] average reconstruction error: 0.00442380
# Epoch [3761 / 8000] average reconstruction error: 0.00447442
# Epoch [3771 / 8000] average reconstruction error: 0.00437544
# Epoch [3781 / 8000] average reconstruction error: 0.00432905
# Epoch [3791 / 8000] average reconstruction error: 0.00447332
# Epoch [3801 / 8000] average reconstruction error: 0.00435496
# Epoch [3811 / 8000] average reconstruction error: 0.00427801
# Epoch [3821 / 8000] average reconstruction error: 0.00445141
# Epoch [3831 / 8000] average reconstruction error: 0.00429382
# Epoch [3841 / 8000] average reconstruction error: 0.00432011
# Epoch [3851 / 8000] average reconstruction error: 0.00436708
# Epoch [3861 / 8000] average reconstruction error: 0.00442924
# Epoch [3871 / 8000] average reconstruction error: 0.00435644
# Epoch [3881 / 8000] average reconstruction error: 0.00422285
# Epoch [3891 / 8000] average reconstruction error: 0.00419672
# Epoch [3901 / 8000] average reconstruction error: 0.00432875
# Epoch [3911 / 8000] average reconstruction error: 0.00423017
# Epoch [3921 / 8000] average reconstruction error: 0.00422772
# Epoch [3931 / 8000] average reconstruction error: 0.00421036
# Epoch [3941 / 8000] average reconstruction error: 0.01833145
# Epoch [3951 / 8000] average reconstruction error: 0.05542483
# Epoch [3961 / 8000] average reconstruction error: 0.06535525
# Epoch [3971 / 8000] average reconstruction error: 0.05434977
# Epoch [3981 / 8000] average reconstruction error: 0.05414953
# Epoch [3991 / 8000] average reconstruction error: 0.05040369
# Epoch [4001 / 8000] average reconstruction error: 0.05271438
# Epoch [4011 / 8000] average reconstruction error: 0.04747088
# Epoch [4021 / 8000] average reconstruction error: 0.04301719
# Epoch [4031 / 8000] average reconstruction error: 0.04414444
# Epoch [4041 / 8000] average reconstruction error: 0.03704983
# Epoch [4051 / 8000] average reconstruction error: 0.03749696
# Epoch [4061 / 8000] average reconstruction error: 0.02766651
# Epoch [4071 / 8000] average reconstruction error: 0.02922171
# Epoch [4081 / 8000] average reconstruction error: 0.02496587
# Epoch [4091 / 8000] average reconstruction error: 0.02260578
# Epoch [4101 / 8000] average reconstruction error: 0.02109048
# Epoch [4111 / 8000] average reconstruction error: 0.01964847
# Epoch [4121 / 8000] average reconstruction error: 0.01801647
# Epoch [4131 / 8000] average reconstruction error: 0.01589860
# Epoch [4141 / 8000] average reconstruction error: 0.01331374
# Epoch [4151 / 8000] average reconstruction error: 0.01091069
# Epoch [4161 / 8000] average reconstruction error: 0.00904284
# Epoch [4171 / 8000] average reconstruction error: 0.00776479
# Epoch [4181 / 8000] average reconstruction error: 0.00700889
# Epoch [4191 / 8000] average reconstruction error: 0.00659532
# Epoch [4201 / 8000] average reconstruction error: 0.00636803
# Epoch [4211 / 8000] average reconstruction error: 0.00623368
# Epoch [4221 / 8000] average reconstruction error: 0.00614179
# Epoch [4231 / 8000] average reconstruction error: 0.00606591
# Epoch [4241 / 8000] average reconstruction error: 0.00599771
# Epoch [4251 / 8000] average reconstruction error: 0.00593399
# Epoch [4261 / 8000] average reconstruction error: 0.00587243
# Epoch [4271 / 8000] average reconstruction error: 0.00580937
# Epoch [4281 / 8000] average reconstruction error: 0.00575036
# Epoch [4291 / 8000] average reconstruction error: 0.00569022
# Epoch [4301 / 8000] average reconstruction error: 0.00563238
# Epoch [4311 / 8000] average reconstruction error: 0.00557290
# Epoch [4321 / 8000] average reconstruction error: 0.00551523
# Epoch [4331 / 8000] average reconstruction error: 0.00545829
# Epoch [4341 / 8000] average reconstruction error: 0.00540199
# Epoch [4351 / 8000] average reconstruction error: 0.00534565
# Epoch [4361 / 8000] average reconstruction error: 0.00529127
# Epoch [4371 / 8000] average reconstruction error: 0.00523562
# Epoch [4381 / 8000] average reconstruction error: 0.00518485
# Epoch [4391 / 8000] average reconstruction error: 0.00513432
# Epoch [4401 / 8000] average reconstruction error: 0.00508279
# Epoch [4411 / 8000] average reconstruction error: 0.00503396
# Epoch [4421 / 8000] average reconstruction error: 0.00498466
# Epoch [4431 / 8000] average reconstruction error: 0.00493741
# Epoch [4441 / 8000] average reconstruction error: 0.00489111
# Epoch [4451 / 8000] average reconstruction error: 0.00484604
# Epoch [4461 / 8000] average reconstruction error: 0.00480308
# Epoch [4471 / 8000] average reconstruction error: 0.00476162
# Epoch [4481 / 8000] average reconstruction error: 0.00471964
# Epoch [4491 / 8000] average reconstruction error: 0.00468220
# Epoch [4501 / 8000] average reconstruction error: 0.00464282
# Epoch [4511 / 8000] average reconstruction error: 0.00460599
# Epoch [4521 / 8000] average reconstruction error: 0.00457045
# Epoch [4531 / 8000] average reconstruction error: 0.00453418
# Epoch [4541 / 8000] average reconstruction error: 0.00450193
# Epoch [4551 / 8000] average reconstruction error: 0.00446877
# Epoch [4561 / 8000] average reconstruction error: 0.00443727
# Epoch [4571 / 8000] average reconstruction error: 0.00440554
# Epoch [4581 / 8000] average reconstruction error: 0.00437628
# Epoch [4591 / 8000] average reconstruction error: 0.00434666
# Epoch [4601 / 8000] average reconstruction error: 0.00431941
# Epoch [4611 / 8000] average reconstruction error: 0.00429151
# Epoch [4621 / 8000] average reconstruction error: 0.00426509
# Epoch [4631 / 8000] average reconstruction error: 0.00423904
# Epoch [4641 / 8000] average reconstruction error: 0.00421333
# Epoch [4651 / 8000] average reconstruction error: 0.00418901
# Epoch [4661 / 8000] average reconstruction error: 0.00416542
# Epoch [4671 / 8000] average reconstruction error: 0.00414190
# Epoch [4681 / 8000] average reconstruction error: 0.00411851
# Epoch [4691 / 8000] average reconstruction error: 0.00409686
# Epoch [4701 / 8000] average reconstruction error: 0.00407370
# Epoch [4711 / 8000] average reconstruction error: 0.00405355
# Epoch [4721 / 8000] average reconstruction error: 0.00403143
# Epoch [4731 / 8000] average reconstruction error: 0.00401276
# Epoch [4741 / 8000] average reconstruction error: 0.00399267
# Epoch [4751 / 8000] average reconstruction error: 0.00397295
# Epoch [4761 / 8000] average reconstruction error: 0.00395307
# Epoch [4771 / 8000] average reconstruction error: 0.00393466
# Epoch [4781 / 8000] average reconstruction error: 0.00391570
# Epoch [4791 / 8000] average reconstruction error: 0.00389714
# Epoch [4801 / 8000] average reconstruction error: 0.00387852
# Epoch [4811 / 8000] average reconstruction error: 0.00386078
# Epoch [4821 / 8000] average reconstruction error: 0.00384323
# Epoch [4831 / 8000] average reconstruction error: 0.00382658
# Epoch [4841 / 8000] average reconstruction error: 0.00380918
# Epoch [4851 / 8000] average reconstruction error: 0.00379359
# Epoch [4861 / 8000] average reconstruction error: 0.00377562
# Epoch [4871 / 8000] average reconstruction error: 0.00375968
# Epoch [4881 / 8000] average reconstruction error: 0.00374246
# Epoch [4891 / 8000] average reconstruction error: 0.00372665
# Epoch [4901 / 8000] average reconstruction error: 0.00371060
# Epoch [4911 / 8000] average reconstruction error: 0.00369478
# Epoch [4921 / 8000] average reconstruction error: 0.00368022
# Epoch [4931 / 8000] average reconstruction error: 0.00366403
# Epoch [4941 / 8000] average reconstruction error: 0.00364991
# Epoch [4951 / 8000] average reconstruction error: 0.00363393
# Epoch [4961 / 8000] average reconstruction error: 0.00361897
# Epoch [4971 / 8000] average reconstruction error: 0.00360399
# Epoch [4981 / 8000] average reconstruction error: 0.00359031
# Epoch [4991 / 8000] average reconstruction error: 0.00359122
# Epoch [5001 / 8000] average reconstruction error: 0.00356137
# Epoch [5011 / 8000] average reconstruction error: 0.00361426
# Epoch [5021 / 8000] average reconstruction error: 0.00361698
# Epoch [5031 / 8000] average reconstruction error: 0.00356136
# Epoch [5041 / 8000] average reconstruction error: 0.00358061
# Epoch [5051 / 8000] average reconstruction error: 0.00350037
# Epoch [5061 / 8000] average reconstruction error: 0.00359775
# Epoch [5071 / 8000] average reconstruction error: 0.00347760
# Epoch [5081 / 8000] average reconstruction error: 0.00347657
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Documents\rpoditela\Intra\autoencoder\autoencoder_5at.ipynb Celda 26 in <cell line: 7>()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=56'>57</a> #print("total_loss", total_loss)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=59'>60</a> opt.zero_grad()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=60'>61</a> total_loss.backward(retain_graph=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=61'>62</a> opt.step()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=62'>63</a> #scheduler.step()
#
# File c:\Users\User\anaconda3\envs\py_torc\lib\site-packages\torch\_tensor.py:363, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     354 if has_torch_function_unary(self):
#     355     return handle_torch_function(
#     356         Tensor.backward,
#     357         (self,),
#    (...)
#     361         create_graph=create_graph,
#     362         inputs=inputs)
# --> 363 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File c:\Users\User\anaconda3\envs\py_torc\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
encoder = GRASSEncoder(input_size = 5, feature_size=128, hidden_size=256).to(device)
decoder = GRASSDecoder(latent_size=128, hidden_size=256, mult = mult).to(device)

checkpoint = torch.load("outputs/best_model.pth")
encoder.load_state_dict(checkpoint['encoder_state_dict'])
decoder.load_state_dict(checkpoint['decoder_state_dict'])
epoch = checkpoint['epoch']
print("epoch", epoch)
# Out:
# epoch 5082

# %%
input = iter(data_loader).next()[0]
enc_fold = torch_f.Fold(device)
enc_fold_nodes = []
enc_fold_nodes.append(encode_structure_fold(enc_fold, input))
enc_fold_nodes = enc_fold.apply(encoder, [enc_fold_nodes])
encoded = enc_fold_nodes[0]
decoded = decode_testing_grass(encoded, input, 100, decoder)

count = []
numerar_nodos(decoded, count)
decoded.traverseInorder(decoded)
# Out:
# 0 tensor([[0.5510, 0.4789, 0.2155, 0.2175, 1.0029]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 1 tensor([[0.5281, 0.4719, 0.2243, 0.1697, 1.0488]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2 tensor([[0.5161, 0.4887, 0.2902, 0.1826, 1.0652]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 3 tensor([[0.5038, 0.4745, 0.3202, 0.1878, 1.0346]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 4 tensor([[0.4887, 0.4564, 0.3372, 0.1956, 1.0121]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 5 tensor([[0.4731, 0.4394, 0.3444, 0.2050, 1.0015]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 6 tensor([[0.4543, 0.4210, 0.3431, 0.2155, 0.9984]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 7 tensor([[0.4312, 0.3995, 0.3346, 0.2277, 0.9994]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 8 tensor([[0.4033, 0.3743, 0.3200, 0.2425, 1.0020]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 9 tensor([[0.3708, 0.3448, 0.3002, 0.2619, 1.0039]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 10 tensor([[0.3334, 0.3108, 0.2761, 0.2882, 1.0014]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 11 tensor([[0.2918, 0.2729, 0.2486, 0.3239, 0.9888]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 12 tensor([[0.2483, 0.2322, 0.2211, 0.3717, 0.9544]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 13 tensor([[0.2068, 0.1931, 0.2020, 0.4273, 0.8753]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 14 tensor([[0.0388, 0.1861, 0.1640, 0.2195, 0.6106]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 15 tensor([[0.0956, 0.1853, 0.1929, 0.1739, 0.5513]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 16 tensor([[0.0782, 0.1531, 0.1264, 0.1222, 0.5509]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 17 tensor([[0.0394, 0.1134, 0.0690, 0.1008, 0.5346]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 18 tensor([[0.1742, 0.1618, 0.2128, 0.4686, 0.7160]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 19 tensor([[0.0265, 0.1489, 0.1908, 0.2002, 0.5079]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 20 tensor([[0.0977, 0.1811, 0.2439, 0.1809, 0.5087]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 21 tensor([[0.0724, 0.1411, 0.1568, 0.1247, 0.5100]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 22 tensor([[0.0330, 0.1022, 0.0928, 0.1029, 0.5007]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 23 tensor([[0.1531, 0.1443, 0.2878, 0.4453, 0.4630]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 24 tensor([[0.0224, 0.1156, 0.2227, 0.1836, 0.4085]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 25 tensor([[0.1053, 0.1815, 0.2946, 0.1892, 0.4746]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 26 tensor([[0.0708, 0.1344, 0.1858, 0.1288, 0.4799]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 27 tensor([[0.0290, 0.0946, 0.1134, 0.1055, 0.4759]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 28 tensor([[0.1377, 0.1330, 0.4287, 0.3491, 0.1995]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 29 tensor([[0.1265, 0.1167, 0.5696, 0.2635, 0.0412]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 30 tensor([[ 0.1203,  0.1034,  0.6602,  0.2234, -0.0189]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 31 tensor([[ 0.1161,  0.0959,  0.7058,  0.2089, -0.0361]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 32 tensor([[0.5754, 0.4994, 0.2233, 0.1747, 1.0195]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 33 tensor([[0.6127, 0.5010, 0.2442, 0.1117, 0.9961]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 34 tensor([[0.6062, 0.5120, 0.1670, 0.1055, 0.9734]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 35 tensor([[0.6275, 0.5362, 0.1474, 0.1108, 0.9739]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 36 tensor([[0.6494, 0.5609, 0.1442, 0.1159, 0.9789]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 37 tensor([[0.6688, 0.5822, 0.1462, 0.1202, 0.9835]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 38 tensor([[0.6862, 0.6009, 0.1500, 0.1237, 0.9877]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 39 tensor([[0.7014, 0.6169, 0.1546, 0.1268, 0.9910]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 40 tensor([[0.7150, 0.6315, 0.1595, 0.1292, 0.9936]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 41 tensor([[0.7282, 0.6452, 0.1648, 0.1315, 0.9962]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 42 tensor([[0.7403, 0.6581, 0.1702, 0.1338, 0.9984]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 43 tensor([[0.7522, 0.6704, 0.1756, 0.1357, 1.0005]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 44 tensor([[0.7640, 0.6827, 0.1817, 0.1377, 1.0022]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 45 tensor([[0.7761, 0.6951, 0.1880, 0.1396, 1.0038]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 46 tensor([[0.7883, 0.7076, 0.1951, 0.1415, 1.0054]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 47 tensor([[0.8010, 0.7207, 0.2028, 0.1434, 1.0070]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 48 tensor([[0.8141, 0.7343, 0.2112, 0.1454, 1.0084]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 49 tensor([[0.8284, 0.7488, 0.2209, 0.1475, 1.0097]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 50 tensor([[0.8435, 0.7641, 0.2319, 0.1494, 1.0109]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 51 tensor([[0.8600, 0.7809, 0.2449, 0.1518, 1.0120]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 52 tensor([[0.8777, 0.7989, 0.2597, 0.1539, 1.0126]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 53 tensor([[0.8968, 0.8179, 0.2770, 0.1562, 1.0129]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 54 tensor([[0.9172, 0.8382, 0.2974, 0.1587, 1.0125]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 55 tensor([[0.9381, 0.8590, 0.3207, 0.1611, 1.0111]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 56 tensor([[0.9589, 0.8797, 0.3474, 0.1633, 1.0087]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 57 tensor([[0.9783, 0.8984, 0.3766, 0.1656, 1.0047]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 58 tensor([[0.9946, 0.9140, 0.4077, 0.1677, 0.9988]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 59 tensor([[1.0058, 0.9243, 0.4384, 0.1695, 0.9914]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 60 tensor([[1.0112, 0.9290, 0.4670, 0.1711, 0.9826]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 61 tensor([[1.0110, 0.9281, 0.4921, 0.1725, 0.9728]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
plotTree(input, False)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.5, 0.5,…

# %%
plotTree(decoded, True)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.5167508…

# %%
c = []
n_nodes = input.count_nodes(input,c)
len(n_nodes)
# Out:
# 70

# %%
c = []
n_nodes = decoded.count_nodes(decoded,c)
len(n_nodes)
# Out:
# 62

# %%
li = []
decoded.traverseInorderChilds(decoded, li)
zero = [a for a in li if a == 0]
one = [a for a in li if a == 1]
two = [a for a in li if a == 2]
qzero = len(zero)
qOne = len(one)
qtwo = len(two)
print(qzero, qOne, qtwo)
# Out:
# 5 53 4

# %%
li = []
input.traverseInorderChilds(input, li)
zero = [a for a in li if a == 0]
one = [a for a in li if a == 1]
two = [a for a in li if a == 2]
qzero = len(zero)
qOne = len(one)
qtwo = len(two)
print(qzero, qOne, qtwo)
# Out:
# 3 65 2

# %%
def traverseleaf(root):
    if root is not None:
        traverseleaf(root.left)
        if root.is_leaf():
            print(root.radius)
        traverseleaf(root.right)
        return 

def traversebif(root):
    if root is not None:
        traversebif(root.left)
        if root.is_two_child():
            print(root.radius)
        traversebif(root.right)
        return

# %%
traversebif(decoded)
print("////")
traversebif(input)
# Out:
# tensor([[0.1742, 0.1618, 0.2128, 0.4686, 0.7160]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.1531, 0.1443, 0.2878, 0.4453, 0.4630]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.1377, 0.1330, 0.4287, 0.3491, 0.1995]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.5754, 0.4994, 0.2233, 0.1747, 1.0195]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ////
# tensor([0.1163, 0.1714, 0.2870, 1.0000, 0.0000], device='cuda:0')
# tensor([0.5789, 0.5054, 0.2145, 0.1945, 1.0000], device='cuda:0')

# %%
traverseleaf(decoded)
print("////")
traverseleaf(input)
# Out:
# tensor([[0.0394, 0.1134, 0.0690, 0.1008, 0.5346]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.0330, 0.1022, 0.0928, 0.1029, 0.5007]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.0290, 0.0946, 0.1134, 0.1055, 0.4759]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[ 0.1161,  0.0959,  0.7058,  0.2089, -0.0361]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[1.0110, 0.9281, 0.4921, 0.1725, 0.9728]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ////
# tensor([0.0446, 0.0000, 0.0000, 0.0500, 0.5000], device='cuda:0')
# tensor([0.0634, 0.1035, 1.0000, 0.3390, 0.0000], device='cuda:0')
# tensor([0.9985, 1.0000, 0.6220, 0.2447, 1.0000], device='cuda:0')
