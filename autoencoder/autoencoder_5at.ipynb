# %%
from logging import raiseExceptions
from tokenize import Double
import networkx as nx
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import os
import numpy as np
from vec3 import Vec3
import meshplot as mp
import torch
torch.manual_seed(125)
import random
random.seed(125)
import torch_f as torch_f

# %%
def count_fn(f):
    def wrapper(*args, **kwargs):
        wrapper.count += 1
        return f(*args, **kwargs)
    wrapper.count = 0
    return wrapper

# %% [markdown]
# Clase Nodo

# %%
class Node:
    """
    Class Node
    """
    def __init__(self, value, radius, left = None, right = None, position = None, cl_prob= None, ce = None, mse = None, level = None, treelevel = None):
        self.left = left
        self.data = value
        self.radius = radius
        self.position = position
        self.right = right
        self.prob = cl_prob
        self.mse = mse
        self.ce = ce
        self.children = [self.left, self.right]
        self.level = level
        self.treelevel = treelevel
    
    def agregarHijo(self, children):

        if self.right is None:
            self.right = children
        elif self.left is None:
            self.left = children

        else:
            raise ValueError ("solo arbol binario ")


    def is_leaf(self):
        if self.right is None:
            return True
        else:
            return False

    def is_two_child(self):
        if self.right is not None and self.left is not None:
            return True
        else:
            return False

    def is_one_child(self):
        if self.is_two_child():
            return False
        elif self.is_leaf():
            return False
        else:
            return True

    def childs(self):
        if self.is_leaf():
            return 0
        if self.is_one_child():
            return 1
        else:
            return 2
    
    
    def traverseInorder(self, root):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorder(root.left)
            print (root.data, root.radius)
            self.traverseInorder(root.right)

    def traverseInorderwl(self, root):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderwl(root.left)
            print (root.data, root.radius, root.level, root.treelevel)
            self.traverseInorderwl(root.right)

    def get_tree_level(self, root, c):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.get_tree_level(root.left, c)
            c.append(root.level)
            self.get_tree_level(root.right, c)

    def set_tree_level(self, root, c):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.set_tree_level(root.left, c)
            root.treelevel = c
            self.set_tree_level(root.right, c)

    def traverseInorderLoss(self, root, loss):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderLoss(root.left, loss)
            loss.append(root.prob)
            self.traverseInorderLoss(root.right, loss)
            return loss

    def traverseInorderMSE(self, root, loss):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderMSE(root.left, loss)
            loss.append(root.mse)
            self.traverseInorderMSE(root.right, loss)
            return loss

    def traverseInorderCE(self, root, loss):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderCE(root.left, loss)
            loss.append(root.ce)
            self.traverseInorderCE(root.right, loss)
            return loss

    def traverseInorderChilds(self, root, l):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            self.traverseInorderChilds(root.left, l)
            l.append(root.childs())
            self.traverseInorderChilds(root.right, l)
            return l

    def preorder(self, root):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            print (root.data, root.radius)
            self.preorder(root.left)
            self.preorder(root.right)

    def cloneBinaryTree(self, root):
     
        # base case
        if root is None:
            return None
    
        # create a new node with the same data as the root node
        root_copy = Node(root.data, root.radius)
    
        # clone the left and right subtree
        root_copy.left = self.cloneBinaryTree(root.left)
        root_copy.right = self.cloneBinaryTree(root.right)
    
        # return cloned root node
        return root_copy

    def height(self, root):
    # Check if the binary tree is empty
        if root is None:
            return 0 
        # Recursively call height of each node
        leftAns = self.height(root.left)
        rightAns = self.height(root.right)
    
        # Return max(leftHeight, rightHeight) at each iteration
        return max(leftAns, rightAns) + 1

    # Print nodes at a current level
    def printCurrentLevel(self, root, level):
        if root is None:
            return
        if level == 1:
            print(root.data, end=" ")
        elif level > 1:
            self.printCurrentLevel(root.left, level-1)
            self.printCurrentLevel(root.right, level-1)

    def printLevelOrder(self, root):
        h = self.height(root)
        for i in range(1, h+1):
            self.printCurrentLevel(root, i)


    
    def count_nodes(self, root, counter):
        if   root is not None:
            self.count_nodes(root.left, counter)
            counter.append(root.data)
            self.count_nodes(root.right, counter)
            return counter

    
    def serialize(self, root):
        def post_order(root):
            if root:
                post_order(root.left)
                post_order(root.right)
                ret[0] += str(root.data)+'_'+ str(root.radius) +';'
                
            else:
                ret[0] += '#;'           

        ret = ['']
        post_order(root)
        return ret[0][:-1]  # remove last ,

    def toGraph( self, graph, index, dec, proc=True):
        
        
        radius = self.radius.cpu().detach().numpy()
        if dec:
            radius= radius[0]
        #print("posicion", self.data, radius)
        #print("right", self.right)
        
        #graph.add_nodes_from( [ (index, {'posicion': radius[0:3], 'radio': radius[3] } ) ])
        graph.add_nodes_from( [ (self.data, {'posicion': radius[0:3], 'radio': radius[3:] } ) ])
        #print("posicion", radius[0:3])
        #print("radio", radius[3:])

        if self.right is not None:
            #leftIndex = self.right.toGraph( graph, index + 1, dec)#
            self.right.toGraph( graph, index + 1, dec)#
            
            #graph.add_edge( index, index + 1 )
            graph.add_edge( self.data, self.right.data )
            #if proc:
            #    nx.set_edge_attributes( graph, {(index, index+1) : {'procesada':False}})
        
            if self.left is not None:
                #retIndex = self.left.toGraph( graph, leftIndex, dec )#
                self.left.toGraph( graph, 0, dec )#

                #graph.add_edge( index, leftIndex)
                graph.add_edge( self.data, self.left.data)
                #if proc:
                #    nx.set_edge_attributes( graph, {(index, leftIndex) : {'procesada':False}})
            
            else:
                #return leftIndex
                return

        else:
            #return index + 1
            return

# %% [markdown]
# Funciones extra

# %%
use_gpu = True
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")

# %%
def plotTree( root, dec ):
    graph = nx.Graph()
    root.toGraph( graph, 0, dec)
    edges = nx.get_edge_attributes(graph,'procesada')

    p = mp.plot( np.array([ graph.nodes[v]['posicion'] for v in graph.nodes]), shading={'point_size':0.1}, return_plot=True)
    for arista in graph.edges:
        p.add_lines( graph.nodes[arista[0]]['posicion'], graph.nodes[arista[1]]['posicion'])

    return 

def traverse(root, tree):
       
        if root is not None:
            traverse(root.left, tree)
            tree.append((root.radius, root.data))
            traverse(root.right, tree)
            return tree

def traverse_2(tree1, tree2, t_l):
       
        if tree1 is not None:
            traverse_2(tree1.left, tree2.left, t_l)
            if tree2:
                t_l.append((tree1.radius, tree2.radius))
                print((tree1.radius, tree2.radius))
            else:
                t_l.append(tree1.radius)
                print((tree1.radius))
            traverse_2(tree1.right, tree2, t_l)
            return t_l
            

def traverse_conexiones(root, tree):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            traverse_conexiones(root.left, tree)
            if root.right is not None:
                tree.append((root.data, root.right.data))
            if root.left is not None:
                tree.append((root.data, root.left.data))
            traverse_conexiones(root.right, tree)
            return tree

def arbolAGrafo (nodoRaiz):
    
    conexiones = []
    lineas = traverse_conexiones(nodoRaiz, conexiones)
    tree = []
    tree = traverse(nodoRaiz, tree)

    vertices = []
    verticesCrudos = []
    for node in tree:
        vertice = node[0][0][:3]
        rad = node[0][0][-1]
        num = node[1]
        
        #vertices.append((num, {'posicion': Vec3( vertice[0], vertice[1], vertice[2]), 'radio': rad} ))
        vertices.append((len(verticesCrudos),{'posicion': Vec3( vertice[0], vertice[1], vertice[2]), 'radio': rad}))
        print("posicion", Vec3( vertice[0], vertice[1], vertice[2]))
        print("radio", rad)
        verticesCrudos.append(vertice)


    G = nx.Graph()
    G.add_nodes_from( vertices )
    G.add_edges_from( lineas )
    
    return G

@count_fn
def createNode(data, radius, position = None, left = None, right = None, cl_prob = None, ce = None, mse=None):
        """
        Utility function to create a node.
        """
        return Node(data, radius, position, left, right, cl_prob, ce, mse)
 
def deserialize(data):
    if  not data:
        return 
    nodes = data.split(';')  
    
    def post_order(nodes):
                
        if nodes[-1] == '#':
            nodes.pop()
            return None
        node = nodes.pop().split('_')
       
        data = int(node[0])
        
        #radius = float(node[1])
        #print("node", node)
        #breakpoint()
        radius = node[1]
        #print("radius", radius)
        rad = radius.split(",")

        rad [0] = rad[0].replace('[','')
        rad [4] = rad[4].replace(']','')
        r = []
        for value in rad:
            r.append(float(value))
        #r =[float(num) for num in radius if num.isdigit()]
        r = torch.tensor(r, device=device)
        #breakpoint()
        root = createNode(data, r)
        root.right = post_order(nodes)
        root.left = post_order(nodes)
        
        return root    
    return post_order(nodes)    


def read_tree(filename):
    with open('./trees/' +filename, "r") as f:
        byte = f.read() 
        return byte

# %% [markdown]
# Encoder

# %%
class InternalEncoder(nn.Module):
    
    def __init__(self, input_size: int, feature_size: int, hidden_size: int):
        super(InternalEncoder, self).__init__()

        #print("init")
        # Encoders atributos
        self.attribute_lin_encoder_1 = nn.Linear(input_size,hidden_size)
        self.attribute_lin_encoder_2 = nn.Linear(hidden_size,feature_size)

        # Encoders derecho e izquierdo
        self.right_lin_encoder_1 = nn.Linear(feature_size,feature_size)
        self.left_lin_encoder_1  = nn.Linear(feature_size,feature_size)

        # Encoder final
        self.final_lin_encoder_1 = nn.Linear(2*feature_size, feature_size)

        # Funciones / Parametros utiles
        self.tanh = nn.Tanh()
        self.feature_size = feature_size
        #print("fin")

    def forward(self, input, right_input, left_input):
        #print("estoy encodeando")
        #print("input", input.shape)
        input = input.reshape(-1,5)
        #print("input", input.shape)

        #print("right input", right_input)
        # Encodeo los atributos
        attributes = self.attribute_lin_encoder_1(input)
        attributes = self.tanh(attributes)
        attributes = self.attribute_lin_encoder_2(attributes)
        attributes = self.tanh(attributes)
        #print("attributes", attributes)

        # Encodeo el derecho
        if right_input is not None:
            #print("right input", right_input)
            context = self.right_lin_encoder_1(right_input)
            #print("context derecho", context)
            # Encodeo el izquierdo
            #print("left input", left_input)
            if left_input is not None:
                
                context += self.left_lin_encoder_1(left_input)
                #print("context izquierdo", context.shape)
        else:
            context = torch.zeros(input.shape[0],self.feature_size, requires_grad=True, device=device)
        

        context = self.tanh(context)
        #print("context shape", context.shape)
        #print("attributes shape", attributes.shape)
        #if len(attributes.shape) == 1:
            #print("len(attributes.shape)",len(attributes.shape))
            #attributes = attributes.reshape(1, 128)
        #print("attributes shape", attributes.shape)

        feature = torch.cat((attributes,context), 1)
        #print("feature cat", feature.shape)

        feature = self.final_lin_encoder_1(feature)
        feature = self.tanh(feature)
        #print("output", feature)
        return feature

        #print("radius", radius.shape)
        #if right_input is not None:
        #    context = self.right(right_input)
        #    #print("context", context.shape)
        #    if left_input is not None:
        #        context += self.left(left_input)
        #        #print("context2", context.shape)
        #    context = self.tanh(context)
        #    #print("context3", context.shape)
        #    feature = torch.cat((radius,context), 1)
        #    #print("feature", feature.shape)
        #    feature = self.encoder(feature)
        #else:
        #    feature = self.l3(radius)
        #    feature = self.tanh(feature)
        #    feature = self.leafencoder(radius)
        #    #print("feature", feature.shape)

        #feature = self.tanh(feature)
        #return feature
    

class GRASSEncoder(nn.Module):
    
    def __init__(self, input_size: int, feature_size : int, hidden_size: int):
        super(GRASSEncoder, self).__init__()
        self.leaf_encoder = InternalEncoder(input_size,feature_size, hidden_size)
        self.internal_encoder = InternalEncoder(input_size,feature_size, hidden_size)
        self.bifurcation_encoder = InternalEncoder(input_size,feature_size, hidden_size)
        
    def leafEncoder(self, node, right=None, left = None):
        return self.internal_encoder(node, right, left)
    def internalEncoder(self, node, right, left = None):
        return self.internal_encoder(node, right, left)
    def bifurcationEncoder(self, node, right, left):
        
        return self.bifurcation_encoder(node, right, left)

Grassencoder = GRASSEncoder(input_size = 5, feature_size=128, hidden_size=256)
Grassencoder = Grassencoder.to(device)


def encode_structure_fold(fold, root):
    
    
    def encode_node(node):
        
        if node is None:
            return
        
        if node.is_leaf():
            return fold.add('leafEncoder', node.radius)
        else:
            left = encode_node(node.left)
            right = encode_node(node.right)
            if left is not None:
             
                return fold.add('bifurcationEncoder', node.radius, right, left)
            else:
                return fold.add('internalEncoder', node.radius, right)
        

    encoding = encode_node(root)
    
    return encoding
  
def encode_structure(root):
    
    def encode_node(node):
          
        if node is None:
            return
        if node.is_leaf():
            return Grassencoder.leafEncoder(node.radius.reshape(-1,4))
        else :
            left = encode_node(node.left)
            right = encode_node(node.right)
            if left is not None:
                return Grassencoder.bifurcationEncoder(node.radius.reshape(-1,4), right, left)
            else:
                return Grassencoder.internalEncoder(node.radius.reshape(-1,4), right)
        

    encoding = encode_node(root)
   
    return encoding

# %% [markdown]
# Extra

# %%
def numerar_nodos(root, count):
    if root is not None:
        numerar_nodos(root.left, count)
        root.data = len(count)
        count.append(1)
        numerar_nodos(root.right, count)
        return 


def traversefeatures(root, features):
       
    if root is not None:
        traversefeatures(root.left, features)
        features.append(root.radius)
        traversefeatures(root.right, features)
        return features

def norm(root, minx, miny, minz, minr, minl, maxx, maxy, maxz, maxr, maxl):
    
    if root is not None:
        mx = minx.clone().detach()
        my = miny.clone().detach()
        mz = minz.clone().detach()
        mr = minr.clone().detach()
        ml = minl.clone().detach()
        Mx = maxx.clone().detach()
        My = maxy.clone().detach()
        Mz = maxz.clone().detach()
        Mr = maxr.clone().detach()
        Ml = maxl.clone().detach()
       
        root.radius[0] = (root.radius[0] - minx)/(maxx - minx)
        root.radius[1] = (root.radius[1] - miny)/(maxy - miny)
        root.radius[2] = (root.radius[2] - minz)/(maxz - minz)
        root.radius[3] = (root.radius[3] - minr)/(maxr - minr)
        root.radius[4] = (root.radius[4] - minl)/(maxl - minl)

        
        norm(root.left, mx, my, mz, mr, ml, Mx, My, Mz, Mr, Ml)
        norm(root.right, mx, my, mz, mr, ml, Mx, My, Mz, Mr, Ml)
        return 

def normalize_features(root):
    features = []
    features = traversefeatures(root, features)

    x = [tensor[0] for tensor in features]
    y = [tensor[1] for tensor in features]
    z = [tensor[2] for tensor in features]
    r = [tensor[3] for tensor in features]
    l = [tensor[4] for tensor in features]


 
    norm(root, min(x), min(y), min(z), min(r), min(l), max(x), max(y), max(z), max(r), max(l))

    return 

def traversefeatures(root, features):
       
    if root is not None:
        traversefeatures(root.left, features)
        features.append(root.radius)
        traversefeatures(root.right, features)
        return features

# %% [markdown]
# Dataloader

# %%
def my_collate(batch):
    return batch

#t_list = ['ArteryObjAN1-7.dat','ArteryObjAN1-0.dat', 'ArteryObjAN1-17.dat',  'ArteryObjAN1-11.dat']

#t_list = ['ArteryObjAN1-0.dat','ArteryObjAN1-7.dat', 'ArteryObjAN1-17.dat',  'ArteryObjAN1-11.dat', 'ArteryObjAN1-19.dat', 'ArteryObjAN2-4.dat', 'ArteryObjAN2-6.dat', 
#           'ArteryObjAN25-18.dat']
t_list = ['ArteryObjAN1-17-nl.dat']


#t_list = ['test2.dat']

#t_list = ['ArteryObjAN31-14.dat']
#t_list = os.listdir("./trees")[:20]
print(t_list)
class tDataset(Dataset):
    def __init__(self, dir, transform=None):
        self.names = dir
        self.transform = transform
        self.data = [] #lista con las strings de todos los arboles
        for file in self.names:
            self.data.append(read_tree(file))
        self.trees = []
        for tree in self.data:
            deserial = deserialize(tree)
            #normalize_features(deserial)
            self.trees.append(deserial)

    def __len__(self):
        return len(self.names)

    def __getitem__(self, idx):
        #file = self.names[idx]
        #string = read_tree(file)
        tree = self.trees[idx]
        return tree

batch_size = 1
dataset = tDataset(t_list)
data_loader = DataLoader(dataset, batch_size = batch_size, shuffle=True, collate_fn=my_collate)
# Out:
# ['ArteryObjAN1-17-nl.dat']

# %%
input = iter(data_loader).next()[0]
plotTree(input, False)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(13.846129…

# %%
n_no = []
qzero = 0
qOne = 0
qtwo = 0

for batch in data_loader:
    for tree in batch:
        count = []
        n = tree.count_nodes(tree, count)
        n_no.append(len(n))
        li = []
        tree.traverseInorderChilds(tree, li)
        zero = [a for a in li if a == 0]
        one = [a for a in li if a == 1]
        two = [a for a in li if a == 2]
        qzero += len(zero)
        qOne += len(one)
        qtwo += len(two)

print(len(data_loader)*batch_size)
print(n_no)
nprom = np.mean(n_no)
print(nprom)
qzero /= len(data_loader)*batch_size
qOne /= len(data_loader)*batch_size
qtwo /= len(data_loader)*batch_size

print(qzero)
print(qOne)
print(qtwo)
# Out:
# 1
# [70]
# 70.0
# 3.0
# 65.0
# 2.0

# %% [markdown]
# clasificador

# %%
class NodeClassifier(nn.Module):
    
    def __init__(self, latent_size : int, hidden_size : int):
        super(NodeClassifier, self).__init__()
        self.mlp1 = nn.Linear(latent_size, hidden_size)
        self.mlp2 = nn.Linear(hidden_size, hidden_size)
        self.mlp3 = nn.Linear(hidden_size, 3)
        self.tanh = nn.Tanh()

    def forward(self, input_feature):
        #print("classifier input", input_feature)
        output = self.mlp1(input_feature)
        output = self.tanh(output)
        output = self.mlp2(output)
        output = self.tanh(output)
        output = self.mlp3(output)
        #print("classifier output", output)

        return output

# %% [markdown]
# decoder

# %%
class Decoder(nn.Module):
    
    """ Decode an input (parent) feature into a left-child and a right-child feature """
    def __init__(self, latent_size : int, hidden_size : int):
        super(Decoder, self).__init__()
        #self.mlp = nn.Linear(latent_size,hidden_size)
        self.mlp = nn.Linear(latent_size,hidden_size)
        self.lp2 = nn.Linear(hidden_size, latent_size)
        self.mlp_left = nn.Linear(latent_size, latent_size)
        self.mlp_right = nn.Linear(latent_size, latent_size)
        self.mlp3 = nn.Linear(latent_size,latent_size)
        self.mlp2 = nn.Linear(latent_size,5)
        self.tanh = nn.Tanh()

    def common_branch(self, parent_feature):
        vector = self.mlp(parent_feature)
        vector = self.tanh(vector)
        vector = self.lp2(vector)
        vector = self.tanh(vector)
        return vector

    def attr_branch(self, vector):
        vector = self.mlp2(vector)        
        return vector

    def right_branch(self, vector):
        right_feature = self.mlp_right(vector)
        right_feature = self.tanh(right_feature)
        return right_feature

    def left_branch(self, vector):
        left_feature = self.mlp_left(vector)
        left_feature = self.tanh(left_feature)
        return left_feature

    def forward(self, parent_feature):
      
        vector      = self.common_branch(parent_feature)
        attr_vector = self.attr_branch(vector)
        return attr_vector 

    def forward1(self, parent_feature):
    

        vector       = self.common_branch(parent_feature)
        attr_vector  = self.attr_branch(vector)
        right_vector = self.right_branch(vector)
        
        #print("right vector", right_vector)
        #print("radius", attr_vector)
        return right_vector, attr_vector

    def forward2(self, parent_feature):
       

        vector       = self.common_branch(parent_feature)
        attr_vector  = self.attr_branch(vector)
        right_vector = self.right_branch(vector)
        left_vector  = self.left_branch(vector)
        #print("left vector", left_vector)
        #print("right vector", right_vector)
        #print("radius", attr_vector)
        return left_vector, right_vector, attr_vector



class GRASSDecoder(nn.Module):
    def __init__(self, latent_size : int, hidden_size: int, mult: torch.Tensor):
        super(GRASSDecoder, self).__init__()
        self.decoder = Decoder(latent_size, hidden_size)
        self.node_classifier = NodeClassifier(latent_size, hidden_size)
        self.mseLoss = nn.MSELoss()  # pytorch's mean squared error loss
        self.ceLoss = nn.CrossEntropyLoss(weight = mult)  # pytorch's cross entropy loss (NOTE: no softmax is needed before)
        


    def featureDecoder(self, feature):
        return self.decoder.forward(feature)

    def internalDecoder(self, feature):
        return self.decoder.forward1(feature)

    def bifurcationDecoder(self, feature):
        return self.decoder.forward2(feature)

    def nodeClassifier(self, feature):
        return self.node_classifier(feature)

    def calcularLossAtributo(self, nodo, radio):
        #print("nodo", nodo)
        #print("radio", radio)
        a, b = list(zip(*nodo))# a son los atributos, b los pesos
        if nodo is None:
            return
        else:
            nodo = torch.stack(list(a))
        
            l = [self.mseLoss(b.reshape(1,5), gt.reshape(1,5)) for b, gt in zip(radio.reshape(-1,5), nodo.reshape(-1,5))]
            #print("mse", l)
            return l


    def classifyLossEstimator(self, label_vector, original):
        if original is None:
            return
        else:
           
            v = []
            for o in original:
                if o == 0:
                    vector = torch.tensor([1, 0, 0], device=device, dtype = torch.float)
                if o == 1:
                    vector = torch.tensor([0, 1, 0], device=device, dtype = torch.float)
                if o == 2:
                    vector = torch.tensor([0, 0, 1], device=device, dtype = torch.float)
                v.append(vector)
            #print("////")
            #print("original", v)
            #print("prediction", label_vector)
            #print("////")

            v = torch.stack(v)
            #for b, gt in zip(label_vector.reshape(-1,3), v.reshape(-1,3)):
            #    print("...")
            #    print("b", b)
            #    print("gt", gt)
            #    print("...")
            l = [self.ceLoss(b.reshape(1,3), gt.reshape(1,3)).mul(0.4) for b, gt in zip(label_vector.reshape(-1,3), v.reshape(-1,3))]
            #print("ce", l)

            return l
            #return c
       # return torch.cat([self.creLoss(l.unsqueeze(0), gt).mul(0.2) for l, gt in zip(label_vector, gt_label_vector)], 0)

    
    def vectorAdder(self, v1, v2):
        v = v1.add(v2)
        return v

    def vectorMult(self, m, v):
        #print("v", v)
        #print("m", m)
        z = zip(v, m)
        r = []
        for c, d in z:
            #print("v", c)
            #print("m", d)
            r.append(torch.mul(c, d))
        #res = [torch.mul(v, m) for v, m in zip(v, m)]
        #print("res", r)
        return r

if round(qzero) == 0:
    qzero = 1
if round(qOne) == 0:
    qOne = 1
if round(qtwo) == 0:
    qtwo = 1

print("qs", qzero, qOne, qtwo)
mult = torch.tensor([1/round(qzero),1/round(qOne),1/round(qtwo)], device = device)

Grassdecoder = GRASSDecoder(latent_size=128, hidden_size=256, mult = mult)
Grassdecoder = Grassdecoder.to(device)
# Out:
# qs 3.0 65.0 2.0

# %%
def searchNode(node, key):
     
    if (node == None):
        return False
 
    if (node.data == key):
        return node
        
 
    """ then recur on left subtree """
    res1 = searchNode(node.left, key)
    # node found, no need to look further
    if res1:
        return res1
 
    """ node is not found in left,
    so recur on right subtree """
    res2 = searchNode(node.right, key)
    return res2

def getLevelUtil(node, data, level):
    if (node == None):
        return 0
 
    if (node.data == data):
        return level
 
    downlevel = getLevelUtil(node.left, data, level + 1)

    if (downlevel != 0):
        return downlevel
 
    downlevel = getLevelUtil(node.right, data, level + 1)
    return downlevel
 
# Returns level of given data value
 
 
def getLevel(node, data):
    return getLevelUtil(node, data, 1)
 

for d in data_loader:
    for data in d:
        print(data)
        count = []
        numerar_nodos(data, count)
        c = []
        n_nodes = data.count_nodes(data, c)
        for x in range(0, len(n_nodes)):
            level = getLevel(data, x)
            if (level):
                #print("Level of", x, "is", getLevel(input, x))
                node = searchNode(data, x)
                node.level = getLevel(data, x)
                #print("node radius", node.radius)
                #print("node radius", node.radius.reshape(1,4).shape)
                #print("node level", torch.tensor(float(node.level), requires_grad=True, device = device))
                #print("node level", torch.tensor(float(node.level), requires_grad=True, device = device).reshape(1,1).shape)
                #node.radius = torch.cat((node.radius.reshape(1,4), torch.tensor(float(node.level), requires_grad=True, device = device).reshape(1,1)),1).reshape(5)
                #print("node radius", node.radius.shape)

            else:
                print(x, "is not present in tree")
        tree_level = []
        data.get_tree_level(data, tree_level)
        print("tree level", sum(tree_level))
        data.set_tree_level(data, sum(tree_level))
        normalize_features(data)
# Out:
# <__main__.Node object at 0x00000152D3F3BAC0>
# tree level 1185

# %%
for d in data_loader:
    for data in d:
        data.traverseInorder(data)
# Out:
# 0 tensor([0.5616, 0.4881, 0.2191, 0.2087, 1.0000], device='cuda:0')
# 1 tensor([0.5440, 0.4732, 0.2243, 0.2027, 1.0000], device='cuda:0')
# 2 tensor([0.5258, 0.4560, 0.2368, 0.1806, 1.0000], device='cuda:0')
# 3 tensor([0.5088, 0.4391, 0.2544, 0.1682, 1.0000], device='cuda:0')
# 4 tensor([0.4922, 0.4232, 0.2691, 0.1621, 1.0000], device='cuda:0')
# 5 tensor([0.4757, 0.4107, 0.2818, 0.1839, 1.0000], device='cuda:0')
# 6 tensor([0.4552, 0.3980, 0.2874, 0.2006, 1.0000], device='cuda:0')
# 7 tensor([0.4357, 0.3855, 0.2870, 0.2136, 1.0000], device='cuda:0')
# 8 tensor([0.4128, 0.3646, 0.3112, 0.2456, 1.0000], device='cuda:0')
# 9 tensor([0.3303, 0.3139, 0.3256, 0.3001, 1.0000], device='cuda:0')
# 10 tensor([0.3130, 0.3037, 0.3267, 0.2871, 1.0000], device='cuda:0')
# 11 tensor([0.2797, 0.2858, 0.3186, 0.3002, 1.0000], device='cuda:0')
# 12 tensor([0.2424, 0.2630, 0.3149, 0.3511, 1.0000], device='cuda:0')
# 13 tensor([0.1990, 0.2435, 0.2849, 0.3648, 1.0000], device='cuda:0')
# 14 tensor([0.1616, 0.2183, 0.2728, 0.3981, 1.0000], device='cuda:0')
# 15 tensor([0.0480, 0.1620, 0.2025, 0.1885, 0.5000], device='cuda:0')
# 16 tensor([0.0471, 0.1617, 0.1982, 0.1928, 0.5000], device='cuda:0')
# 17 tensor([0.0316, 0.1559, 0.1722, 0.1292, 0.5000], device='cuda:0')
# 18 tensor([0.0137, 0.1445, 0.1257, 0.1618, 0.5000], device='cuda:0')
# 19 tensor([0.0067, 0.1302, 0.0938, 0.1567, 0.5000], device='cuda:0')
# 20 tensor([0.0014, 0.1132, 0.0622, 0.1454, 0.5000], device='cuda:0')
# 21 tensor([0.0000, 0.1004, 0.0475, 0.1115, 0.5000], device='cuda:0')
# 22 tensor([0.0014, 0.0887, 0.0369, 0.0922, 0.5000], device='cuda:0')
# 23 tensor([0.0037, 0.0775, 0.0271, 0.0728, 0.5000], device='cuda:0')
# 24 tensor([0.0086, 0.0617, 0.0169, 0.0309, 0.5000], device='cuda:0')
# 25 tensor([0.0152, 0.0482, 0.0068, 0.0180, 0.5000], device='cuda:0')
# 26 tensor([0.0221, 0.0346, 0.0035, 0.0000, 0.5000], device='cuda:0')
# 27 tensor([0.0446, 0.0000, 0.0000, 0.0500, 0.5000], device='cuda:0')
# 28 tensor([0.1163, 0.1714, 0.2870, 1.0000, 0.0000], device='cuda:0')
# 29 tensor([0.1279, 0.1194, 0.3936, 0.1742, 0.0000], device='cuda:0')
# 30 tensor([0.1310, 0.1089, 0.4269, 0.1370, 0.0000], device='cuda:0')
# 31 tensor([0.1331, 0.0966, 0.4698, 0.1165, 0.0000], device='cuda:0')
# 32 tensor([0.1367, 0.0838, 0.5463, 0.1248, 0.0000], device='cuda:0')
# 33 tensor([0.1397, 0.0735, 0.6332, 0.1653, 0.0000], device='cuda:0')
# 34 tensor([0.1374, 0.0682, 0.7149, 0.1795, 0.0000], device='cuda:0')
# 35 tensor([0.1306, 0.0686, 0.7835, 0.1863, 0.0000], device='cuda:0')
# 36 tensor([0.1195, 0.0777, 0.8675, 0.2326, 0.0000], device='cuda:0')
# 37 tensor([0.1043, 0.0832, 0.9164, 0.2217, 0.0000], device='cuda:0')
# 38 tensor([0.0634, 0.1035, 1.0000, 0.3390, 0.0000], device='cuda:0')
# 39 tensor([0.5789, 0.5054, 0.2145, 0.1945, 1.0000], device='cuda:0')
# 40 tensor([0.5960, 0.5207, 0.2056, 0.1700, 1.0000], device='cuda:0')
# 41 tensor([0.6114, 0.5347, 0.1960, 0.1447, 1.0000], device='cuda:0')
# 42 tensor([0.6278, 0.5506, 0.1884, 0.1313, 1.0000], device='cuda:0')
# 43 tensor([0.6430, 0.5657, 0.1783, 0.1104, 1.0000], device='cuda:0')
# 44 tensor([0.6595, 0.5804, 0.1668, 0.1283, 1.0000], device='cuda:0')
# 45 tensor([0.6764, 0.5950, 0.1611, 0.1377, 1.0000], device='cuda:0')
# 46 tensor([0.6919, 0.6085, 0.1569, 0.1548, 1.0000], device='cuda:0')
# 47 tensor([0.7077, 0.6204, 0.1528, 0.1410, 1.0000], device='cuda:0')
# 48 tensor([0.7221, 0.6315, 0.1500, 0.1309, 1.0000], device='cuda:0')
# 49 tensor([0.7357, 0.6426, 0.1507, 0.1254, 1.0000], device='cuda:0')
# 50 tensor([0.7505, 0.6554, 0.1533, 0.1181, 1.0000], device='cuda:0')
# 51 tensor([0.7644, 0.6687, 0.1587, 0.1185, 1.0000], device='cuda:0')
# 52 tensor([0.7810, 0.6845, 0.1669, 0.1084, 1.0000], device='cuda:0')
# 53 tensor([0.8008, 0.7034, 0.1695, 0.0882, 1.0000], device='cuda:0')
# 54 tensor([0.8209, 0.7195, 0.1880, 0.0921, 1.0000], device='cuda:0')
# 55 tensor([0.8394, 0.7371, 0.2081, 0.1146, 1.0000], device='cuda:0')
# 56 tensor([0.8545, 0.7538, 0.2239, 0.1209, 1.0000], device='cuda:0')
# 57 tensor([0.8686, 0.7713, 0.2359, 0.1149, 1.0000], device='cuda:0')
# 58 tensor([0.8831, 0.7861, 0.2549, 0.1117, 1.0000], device='cuda:0')
# 59 tensor([0.9002, 0.8049, 0.2781, 0.1551, 1.0000], device='cuda:0')
# 60 tensor([0.9160, 0.8208, 0.2926, 0.1697, 1.0000], device='cuda:0')
# 61 tensor([0.9274, 0.8349, 0.3052, 0.1741, 1.0000], device='cuda:0')
# 62 tensor([0.9391, 0.8510, 0.3190, 0.1802, 1.0000], device='cuda:0')
# 63 tensor([0.9538, 0.8696, 0.3377, 0.1776, 1.0000], device='cuda:0')
# 64 tensor([0.9657, 0.8867, 0.3622, 0.1812, 1.0000], device='cuda:0')
# 65 tensor([0.9739, 0.9021, 0.3899, 0.1566, 1.0000], device='cuda:0')
# 66 tensor([0.9843, 0.9205, 0.4337, 0.1645, 1.0000], device='cuda:0')
# 67 tensor([0.9941, 0.9472, 0.4795, 0.1831, 1.0000], device='cuda:0')
# 68 tensor([1.0000, 0.9678, 0.5346, 0.1908, 1.0000], device='cuda:0')
# 69 tensor([0.9985, 1.0000, 0.6220, 0.2447, 1.0000], device='cuda:0')

# %%
def decode_structure_fold_grass(fold, v, root):
   
    def decode_node(fold, v, node):
        
        
        if node.childs() == 0 : 

            radio = fold.add('featureDecoder', v)
            lossAtributo = fold.add('calcularLossAtributo', node, radio)

            label = fold.add('nodeClassifier', v)
            
            lossEstructura = fold.add('classifyLossEstimator', label, node)  
            multipl = node.level/node.treelevel
            losse = fold.add('vectorMult', multipl, lossEstructura)
            
            loss =  fold.add('vectorAdder', losse, lossAtributo)       
            return loss

            
            
        elif node.childs() == 1 :
            right, radius = fold.add('internalDecoder', v).split(2)
            label = fold.add('nodeClassifier', v)
            nodoSiguiente = node.right
            if nodoSiguiente is not None:
                right_loss = decode_node(fold, right, nodoSiguiente)

            lossEstructura = fold.add('classifyLossEstimator', label, node)
            lossAtributo = fold.add('calcularLossAtributo', node, radius)
            multipl = node.level/node.treelevel
            losse = fold.add('vectorMult', multipl, lossEstructura)
            loss = fold.add('vectorAdder', losse, lossAtributo)
            
        
            loss2 = fold.add('vectorAdder', loss, right_loss)
            return loss2
            
            

        elif node.childs() == 2 :
            left, right, radius = fold.add('bifurcationDecoder', v).split(3)
            
            label = fold.add('nodeClassifier', v)            
            
            nodoSiguienteRight = node.right
            nodoSiguienteLeft = node.left


            if nodoSiguienteRight is not None:
                right_loss = decode_node(fold, right, nodoSiguienteRight)
             
            if nodoSiguienteLeft is not None:
                left_loss  = decode_node(fold, left, nodoSiguienteLeft)

            multipl = node.level/node.treelevel
            lossEstructura = fold.add('classifyLossEstimator', label, node)
            losse = fold.add('vectorMult', multipl, lossEstructura)
            lossAtributo   = fold.add('calcularLossAtributo', node, radius)
            loss = fold.add('vectorAdder', losse, lossAtributo)
            loss2 = fold.add('vectorAdder', loss, right_loss)
            loss3 = fold.add('vectorAdder', loss2, left_loss)
            
            return loss3
            

    dec = decode_node (fold, v, root)
    return dec

# %%
def decode_testing_grass(v, root, max, decoder):
    def decode_node(v, node, max, decoder):
        cl = decoder.nodeClassifier(v)
        _, label = torch.max(cl, 1)
        label = label.data
        
        
        if label == 0 and createNode.count <= max: ##output del classifier
           
            #lossEstructura = Grassdecoder.classifyLossEstimator(cl, node)
            radio = decoder.featureDecoder(v)
            #print("radius", radio)
            #lossAtrs = Grassdecoder.calcularLossAtributo( node, radio )
           
            return createNode(1,radio)

        elif label == 1 and createNode.count <= max:
       
            right, radius = decoder.internalDecoder(v)
            #print("radius", radius)
            
            d = createNode(1, radius) 
            #print("d", d.radius)
             
            if not node is None:
                if not node.right is None:
                    nodoSiguiente = node.right
                else:
                    nodoSiguiente = None
            else:
                nodoSiguiente = None
            
            d.right = decode_node(right, nodoSiguiente, max, decoder)
            

            return d
       
        elif label == 2 and createNode.count <= max:
            left, right, radius = decoder.bifurcationDecoder(v)
            #print("radius", radius)
            
            d = createNode(1, radius )
  
            if not node is None: #el nodo existe, me fijo si tiene hijo der/izq
                if not node.right is None:
                    nodoSiguienteRight = node.right
                else:
                    nodoSiguienteRight = None
                if not node.left is None:
                    nodoSiguienteLeft = node.left
                else:
                    nodoSiguienteLeft = None
            else: #el nodo no existe
                nodoSiguienteRight = None
                nodoSiguienteLeft = None
            
            d.right = decode_node(right, nodoSiguienteRight, max, decoder)
            d.left = decode_node(left, nodoSiguienteLeft, max, decoder)
            
           
            return d
            
    createNode.count = 0
    dec = decode_node (v, root, max, decoder)
    return dec

# %%
class SaveBestModel:
    """
    Class to save the best model while training. If the current epoch's 
    validation loss is less than the previous least less, then save the
    model state.
    """
    def __init__(
        self, best_valid_loss=float('inf')
    ):
        self.best_valid_loss = best_valid_loss
        
    def __call__(
        self, current_valid_loss, 
        epoch, encoder, decoder, optimizer
    ):
        if current_valid_loss < self.best_valid_loss:
            self.best_valid_loss = current_valid_loss
            #print(f"\nBest validation loss: {self.best_valid_loss}")
            #print(f"\nSaving best model for epoch: {epoch+1}\n")
            #'classifier_state_dict': classifier.state_dict(),
            torch.save({
                'epoch': epoch+1,
                'encoder_state_dict': encoder.state_dict(),
                'decoder_state_dict': decoder.state_dict(),
                
                'optimizer_state_dict': optimizer.state_dict(),
                }, 'outputs/best_model.pth')

save_best_model = SaveBestModel()

# %%
epochs = 10000
learning_rate = 1e-4
params = list(Grassencoder.parameters()) + list(Grassdecoder.parameters()) 

#opt = torch.optim.Adam(params, lr=learning_rate, weight_decay=0.0001) 
opt = torch.optim.Adam(params, lr=learning_rate) 
#opt = torch.optim.SGD(params, lr=learning_rate, momentum = 0.96) 

#scheduler = torch.optim.lr_scheduler.MultiStepLR(opt, milestones=[6000], gamma=10)
import wandb
config = {
  "learning_rate": learning_rate,
  "epochs": epochs,
  "batch_size": batch_size,
  "dataset": t_list,
  "number of trees": len(data_loader)*batch_size,
  "optim": opt
}
wandb.init(project="autoencoder3", entity="paufeldman", config = config)
# Out:
# Finishing last run (ID:1d1eftph) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.139613…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>██▇▇▆▆▆▅▅▅▄▄▄▃▃▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.19956</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-snow-215</strong>: <a href="https://wandb.ai/paufeldman/autoencoder3/runs/1d1eftph" target="_blank">https://wandb.ai/paufeldman/autoencoder3/runs/1d1eftph</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20221124_113559-1d1eftph\logs</code>
# Successfully finished last run (ID:1d1eftph). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>c:\Users\User\Documents\rpoditela\Intra\autoencoder\wandb\run-20221124_113624-i46lk0uh</code>
# Syncing run <strong><a href="https://wandb.ai/paufeldman/autoencoder3/runs/i46lk0uh" target="_blank">logical-wind-216</a></strong> to <a href="https://wandb.ai/paufeldman/autoencoder3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/paufeldman/autoencoder3/runs/i46lk0uh?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
train_loss_avg = []

ce_avg = []
mse_avg = []
lr_list = []
    
for epoch in range(epochs):
    train_loss_avg.append(0)
   #batch es cada arbol del dataloader
    for batch_idx, batch in enumerate(data_loader):
        # Initialize torchfold for *encoding*

        
        enc_fold = torch_f.Fold(device)
        enc_fold_nodes = []     # list of fold nodes for encoding, lista con la "hoja de ruta" de los dos arboles
        # Collect computation nodes recursively from encoding process
        n_nodes = []
        for example in batch: #example es un arbolito
            c = []
            n = example.count_nodes(example, c)
            n_nodes.append(len(n))
            encode_structure_fold(enc_fold, example)
            enc_fold_nodes.append(encode_structure_fold(enc_fold, example))
       
        # Apply the computations on the encoder model
       
        enc_fold_nodes = enc_fold.apply(Grassencoder, [enc_fold_nodes])
        
        
        # Initialize torchfold for *decoding*
        dec_fold = torch_f.Fold(device)
        # Collect computation nodes recursively from decoding process
        dec_fold_nodes = []
        kld_fold_nodes = []

        t_l = []
        for f in enc_fold_nodes:
            for t in f:
                t_l.append(t)
        for example, fnode in zip(batch, t_l): #example es el arbol y fnode el encodeado
            #print("example", example)
            #print("fnode", fnode) 
            #root_code, kl_div = torch.chunk(fnode, 2, 0)
            dec_fold_nodes.append(decode_structure_fold_grass(dec_fold, fnode, example))
        # Apply the computations on the decoder model

                       
        total_loss = dec_fold.apply(Grassdecoder, [dec_fold_nodes])#[0]
        #print("total_loss", total_loss)
        n_nodes = torch.tensor(n_nodes, device = device)
        #print("n", n_nodes)
        total_loss = torch.div(total_loss[0], n_nodes)
        #print("div", total_loss)
        total_loss = total_loss.sum() / len(batch)  #n_nodes[0] #modificar y dividir por el promedio?
        total_loss = total_loss#*10
        
        #print("total_loss", total_loss)
        
        
        opt.zero_grad()
        total_loss.backward(retain_graph=True)
        opt.step()
        #scheduler.step()
        train_loss_avg[-1] += (total_loss.item())
        

    wandb.log({'epoch': epoch+1, 'loss': total_loss})
    save_best_model(
        total_loss, epoch, Grassencoder, Grassdecoder, opt)
    if epoch % 10 == 0:
        print('Epoch [%d / %d] average reconstruction error: %.8f ' % (epoch+1, epochs, total_loss))
# Out:
# Epoch [1 / 10000] average reconstruction error: 0.31160367
# Epoch [11 / 10000] average reconstruction error: 0.25192198
# Epoch [21 / 10000] average reconstruction error: 0.19347693
# Epoch [31 / 10000] average reconstruction error: 0.12784065
# Epoch [41 / 10000] average reconstruction error: 0.08198271
# Epoch [51 / 10000] average reconstruction error: 0.08154106
# Epoch [61 / 10000] average reconstruction error: 0.08205207
# Epoch [71 / 10000] average reconstruction error: 0.08004550
# Epoch [81 / 10000] average reconstruction error: 0.07998826
# Epoch [91 / 10000] average reconstruction error: 0.07972528
# Epoch [101 / 10000] average reconstruction error: 0.07945711
# Epoch [111 / 10000] average reconstruction error: 0.07925887
# Epoch [121 / 10000] average reconstruction error: 0.07906394
# Epoch [131 / 10000] average reconstruction error: 0.07884279
# Epoch [141 / 10000] average reconstruction error: 0.07860196
# Epoch [151 / 10000] average reconstruction error: 0.07832864
# Epoch [161 / 10000] average reconstruction error: 0.07798847
# Epoch [171 / 10000] average reconstruction error: 0.07755648
# Epoch [181 / 10000] average reconstruction error: 0.07694749
# Epoch [191 / 10000] average reconstruction error: 0.07598618
# Epoch [201 / 10000] average reconstruction error: 0.07411437
# Epoch [211 / 10000] average reconstruction error: 0.06850474
# Epoch [221 / 10000] average reconstruction error: 0.06242996
# Epoch [231 / 10000] average reconstruction error: 0.06880362
# Epoch [241 / 10000] average reconstruction error: 0.07397694
# Epoch [251 / 10000] average reconstruction error: 0.07058734
# Epoch [261 / 10000] average reconstruction error: 0.06245352
# Epoch [271 / 10000] average reconstruction error: 0.04060922
# Epoch [281 / 10000] average reconstruction error: 0.05692122
# Epoch [291 / 10000] average reconstruction error: 0.03547147
# Epoch [301 / 10000] average reconstruction error: 0.03063908
# Epoch [311 / 10000] average reconstruction error: 0.02421347
# Epoch [321 / 10000] average reconstruction error: 0.02315310
# Epoch [331 / 10000] average reconstruction error: 0.02287872
# Epoch [341 / 10000] average reconstruction error: 0.02257685
# Epoch [351 / 10000] average reconstruction error: 0.02245550
# Epoch [361 / 10000] average reconstruction error: 0.02232680
# Epoch [371 / 10000] average reconstruction error: 0.02222371
# Epoch [381 / 10000] average reconstruction error: 0.02212983
# Epoch [391 / 10000] average reconstruction error: 0.02204355
# Epoch [401 / 10000] average reconstruction error: 0.02195638
# Epoch [411 / 10000] average reconstruction error: 0.02186752
# Epoch [421 / 10000] average reconstruction error: 0.02177996
# Epoch [431 / 10000] average reconstruction error: 0.02169413
# Epoch [441 / 10000] average reconstruction error: 0.02160592
# Epoch [451 / 10000] average reconstruction error: 0.02151727
# Epoch [461 / 10000] average reconstruction error: 0.02142751
# Epoch [471 / 10000] average reconstruction error: 0.02134291
# Epoch [481 / 10000] average reconstruction error: 0.02125125
# Epoch [491 / 10000] average reconstruction error: 0.02116434
# Epoch [501 / 10000] average reconstruction error: 0.02107259
# Epoch [511 / 10000] average reconstruction error: 0.02098582
# Epoch [521 / 10000] average reconstruction error: 0.02090051
# Epoch [531 / 10000] average reconstruction error: 0.02081049
# Epoch [541 / 10000] average reconstruction error: 0.02072242
# Epoch [551 / 10000] average reconstruction error: 0.02063734
# Epoch [561 / 10000] average reconstruction error: 0.02055110
# Epoch [571 / 10000] average reconstruction error: 0.02046260
# Epoch [581 / 10000] average reconstruction error: 0.02037803
# Epoch [591 / 10000] average reconstruction error: 0.02029380
# Epoch [601 / 10000] average reconstruction error: 0.02020518
# Epoch [611 / 10000] average reconstruction error: 0.02011984
# Epoch [621 / 10000] average reconstruction error: 0.02003282
# Epoch [631 / 10000] average reconstruction error: 0.01999204
# Epoch [641 / 10000] average reconstruction error: 0.02001776
# Epoch [651 / 10000] average reconstruction error: 0.01978262
# Epoch [661 / 10000] average reconstruction error: 0.02783608
# Epoch [671 / 10000] average reconstruction error: 0.02336914
# Epoch [681 / 10000] average reconstruction error: 0.02326017
# Epoch [691 / 10000] average reconstruction error: 0.02014439
# Epoch [701 / 10000] average reconstruction error: 0.01984364
# Epoch [711 / 10000] average reconstruction error: 0.01973489
# Epoch [721 / 10000] average reconstruction error: 0.01950447
# Epoch [731 / 10000] average reconstruction error: 0.01940621
# Epoch [741 / 10000] average reconstruction error: 0.01931503
# Epoch [751 / 10000] average reconstruction error: 0.01922442
# Epoch [761 / 10000] average reconstruction error: 0.01914171
# Epoch [771 / 10000] average reconstruction error: 0.01905753
# Epoch [781 / 10000] average reconstruction error: 0.01897257
# Epoch [791 / 10000] average reconstruction error: 0.01889346
# Epoch [801 / 10000] average reconstruction error: 0.01882526
# Epoch [811 / 10000] average reconstruction error: 0.01913134
# Epoch [821 / 10000] average reconstruction error: 0.02767669
# Epoch [831 / 10000] average reconstruction error: 0.02657474
# Epoch [841 / 10000] average reconstruction error: 0.02043427
# Epoch [851 / 10000] average reconstruction error: 0.03018031
# Epoch [861 / 10000] average reconstruction error: 0.02417212
# Epoch [871 / 10000] average reconstruction error: 0.02068110
# Epoch [881 / 10000] average reconstruction error: 0.01885692
# Epoch [891 / 10000] average reconstruction error: 0.01879711
# Epoch [901 / 10000] average reconstruction error: 0.01855068
# Epoch [911 / 10000] average reconstruction error: 0.01841681
# Epoch [921 / 10000] average reconstruction error: 0.01830383
# Epoch [931 / 10000] average reconstruction error: 0.01818996
# Epoch [941 / 10000] average reconstruction error: 0.01806828
# Epoch [951 / 10000] average reconstruction error: 0.01793755
# Epoch [961 / 10000] average reconstruction error: 0.01779202
# Epoch [971 / 10000] average reconstruction error: 0.01763124
# Epoch [981 / 10000] average reconstruction error: 0.01743682
# Epoch [991 / 10000] average reconstruction error: 0.01720133
# Epoch [1001 / 10000] average reconstruction error: 0.01689495
# Epoch [1011 / 10000] average reconstruction error: 0.01644752
# Epoch [1021 / 10000] average reconstruction error: 0.01568620
# Epoch [1031 / 10000] average reconstruction error: 0.01405557
# Epoch [1041 / 10000] average reconstruction error: 0.02271030
# Epoch [1051 / 10000] average reconstruction error: 0.01473130
# Epoch [1061 / 10000] average reconstruction error: 0.01307861
# Epoch [1071 / 10000] average reconstruction error: 0.01548878
# Epoch [1081 / 10000] average reconstruction error: 0.01229449
# Epoch [1091 / 10000] average reconstruction error: 0.01003935
# Epoch [1101 / 10000] average reconstruction error: 0.00853085
# Epoch [1111 / 10000] average reconstruction error: 0.00764045
# Epoch [1121 / 10000] average reconstruction error: 0.00928178
# Epoch [1131 / 10000] average reconstruction error: 0.04155224
# Epoch [1141 / 10000] average reconstruction error: 0.02933893
# Epoch [1151 / 10000] average reconstruction error: 0.02091963
# Epoch [1161 / 10000] average reconstruction error: 0.02021494
# Epoch [1171 / 10000] average reconstruction error: 0.01754585
# Epoch [1181 / 10000] average reconstruction error: 0.01761515
# Epoch [1191 / 10000] average reconstruction error: 0.01610690
# Epoch [1201 / 10000] average reconstruction error: 0.01480831
# Epoch [1211 / 10000] average reconstruction error: 0.01343125
# Epoch [1221 / 10000] average reconstruction error: 0.06854907
# Epoch [1231 / 10000] average reconstruction error: 0.08872514
# Epoch [1241 / 10000] average reconstruction error: 0.07542980
# Epoch [1251 / 10000] average reconstruction error: 0.07348084
# Epoch [1261 / 10000] average reconstruction error: 0.06468849
# Epoch [1271 / 10000] average reconstruction error: 0.06179923
# Epoch [1281 / 10000] average reconstruction error: 0.05972588
# Epoch [1291 / 10000] average reconstruction error: 0.05869675
# Epoch [1301 / 10000] average reconstruction error: 0.05809485
# Epoch [1311 / 10000] average reconstruction error: 0.05756109
# Epoch [1321 / 10000] average reconstruction error: 0.05706565
# Epoch [1331 / 10000] average reconstruction error: 0.05652027
# Epoch [1341 / 10000] average reconstruction error: 0.05587997
# Epoch [1351 / 10000] average reconstruction error: 0.05509747
# Epoch [1361 / 10000] average reconstruction error: 0.05401734
# Epoch [1371 / 10000] average reconstruction error: 0.05232678
# Epoch [1381 / 10000] average reconstruction error: 0.04917355
# Epoch [1391 / 10000] average reconstruction error: 0.04443017
# Epoch [1401 / 10000] average reconstruction error: 0.06047157
# Epoch [1411 / 10000] average reconstruction error: 0.03831085
# Epoch [1421 / 10000] average reconstruction error: 0.03462536
# Epoch [1431 / 10000] average reconstruction error: 0.03191265
# Epoch [1441 / 10000] average reconstruction error: 0.03003356
# Epoch [1451 / 10000] average reconstruction error: 0.02796816
# Epoch [1461 / 10000] average reconstruction error: 0.02710914
# Epoch [1471 / 10000] average reconstruction error: 0.02644552
# Epoch [1481 / 10000] average reconstruction error: 0.02577363
# Epoch [1491 / 10000] average reconstruction error: 0.02519166
# Epoch [1501 / 10000] average reconstruction error: 0.02487558
# Epoch [1511 / 10000] average reconstruction error: 0.02460724
# Epoch [1521 / 10000] average reconstruction error: 0.02439363
# Epoch [1531 / 10000] average reconstruction error: 0.02418919
# Epoch [1541 / 10000] average reconstruction error: 0.02398114
# Epoch [1551 / 10000] average reconstruction error: 0.02375889
# Epoch [1561 / 10000] average reconstruction error: 0.02354441
# Epoch [1571 / 10000] average reconstruction error: 0.02329314
# Epoch [1581 / 10000] average reconstruction error: 0.02301950
# Epoch [1591 / 10000] average reconstruction error: 0.02270307
# Epoch [1601 / 10000] average reconstruction error: 0.02236014
# Epoch [1611 / 10000] average reconstruction error: 0.02196455
# Epoch [1621 / 10000] average reconstruction error: 0.02152714
# Epoch [1631 / 10000] average reconstruction error: 0.02105328
# Epoch [1641 / 10000] average reconstruction error: 0.02053854
# Epoch [1651 / 10000] average reconstruction error: 0.01996056
# Epoch [1661 / 10000] average reconstruction error: 0.01927830
# Epoch [1671 / 10000] average reconstruction error: 0.01841729
# Epoch [1681 / 10000] average reconstruction error: 0.01732527
# Epoch [1691 / 10000] average reconstruction error: 0.01573663
# Epoch [1701 / 10000] average reconstruction error: 0.01333592
# Epoch [1711 / 10000] average reconstruction error: 0.00953162
# Epoch [1721 / 10000] average reconstruction error: 0.06714318
# Epoch [1731 / 10000] average reconstruction error: 0.04405746
# Epoch [1741 / 10000] average reconstruction error: 0.03104340
# Epoch [1751 / 10000] average reconstruction error: 0.02880471
# Epoch [1761 / 10000] average reconstruction error: 0.02627083
# Epoch [1771 / 10000] average reconstruction error: 0.02459709
# Epoch [1781 / 10000] average reconstruction error: 0.02338086
# Epoch [1791 / 10000] average reconstruction error: 0.02224071
# Epoch [1801 / 10000] average reconstruction error: 0.02106401
# Epoch [1811 / 10000] average reconstruction error: 0.01994905
# Epoch [1821 / 10000] average reconstruction error: 0.01896459
# Epoch [1831 / 10000] average reconstruction error: 0.01814212
# Epoch [1841 / 10000] average reconstruction error: 0.01744917
# Epoch [1851 / 10000] average reconstruction error: 0.01682663
# Epoch [1861 / 10000] average reconstruction error: 0.01623241
# Epoch [1871 / 10000] average reconstruction error: 0.01564742
# Epoch [1881 / 10000] average reconstruction error: 0.01505625
# Epoch [1891 / 10000] average reconstruction error: 0.01445302
# Epoch [1901 / 10000] average reconstruction error: 0.01385317
# Epoch [1911 / 10000] average reconstruction error: 0.01325178
# Epoch [1921 / 10000] average reconstruction error: 0.01266052
# Epoch [1931 / 10000] average reconstruction error: 0.01210287
# Epoch [1941 / 10000] average reconstruction error: 0.01159980
# Epoch [1951 / 10000] average reconstruction error: 0.01116921
# Epoch [1961 / 10000] average reconstruction error: 0.01079957
# Epoch [1971 / 10000] average reconstruction error: 0.01048790
# Epoch [1981 / 10000] average reconstruction error: 0.01021818
# Epoch [1991 / 10000] average reconstruction error: 0.00998011
# Epoch [2001 / 10000] average reconstruction error: 0.00977207
# Epoch [2011 / 10000] average reconstruction error: 0.00958672
# Epoch [2021 / 10000] average reconstruction error: 0.00941922
# Epoch [2031 / 10000] average reconstruction error: 0.00926986
# Epoch [2041 / 10000] average reconstruction error: 0.00913245
# Epoch [2051 / 10000] average reconstruction error: 0.00900590
# Epoch [2061 / 10000] average reconstruction error: 0.00889018
# Epoch [2071 / 10000] average reconstruction error: 0.00878273
# Epoch [2081 / 10000] average reconstruction error: 0.00870352
# Epoch [2091 / 10000] average reconstruction error: 0.00874569
# Epoch [2101 / 10000] average reconstruction error: 0.00894098
# Epoch [2111 / 10000] average reconstruction error: 0.00862716
# Epoch [2121 / 10000] average reconstruction error: 0.00859249
# Epoch [2131 / 10000] average reconstruction error: 0.00841167
# Epoch [2141 / 10000] average reconstruction error: 0.00826163
# Epoch [2151 / 10000] average reconstruction error: 0.00816458
# Epoch [2161 / 10000] average reconstruction error: 0.00830603
# Epoch [2171 / 10000] average reconstruction error: 0.00833080
# Epoch [2181 / 10000] average reconstruction error: 0.00836071
# Epoch [2191 / 10000] average reconstruction error: 0.01264246
# Epoch [2201 / 10000] average reconstruction error: 0.02409199
# Epoch [2211 / 10000] average reconstruction error: 0.02295569
# Epoch [2221 / 10000] average reconstruction error: 0.01390338
# Epoch [2231 / 10000] average reconstruction error: 0.01127609
# Epoch [2241 / 10000] average reconstruction error: 0.00987381
# Epoch [2251 / 10000] average reconstruction error: 0.00911264
# Epoch [2261 / 10000] average reconstruction error: 0.00872590
# Epoch [2271 / 10000] average reconstruction error: 0.00842819
# Epoch [2281 / 10000] average reconstruction error: 0.00820962
# Epoch [2291 / 10000] average reconstruction error: 0.00804649
# Epoch [2301 / 10000] average reconstruction error: 0.00791643
# Epoch [2311 / 10000] average reconstruction error: 0.00782013
# Epoch [2321 / 10000] average reconstruction error: 0.00773043
# Epoch [2331 / 10000] average reconstruction error: 0.00766137
# Epoch [2341 / 10000] average reconstruction error: 0.00760438
# Epoch [2351 / 10000] average reconstruction error: 0.00755606
# Epoch [2361 / 10000] average reconstruction error: 0.00751921
# Epoch [2371 / 10000] average reconstruction error: 0.00747214
# Epoch [2381 / 10000] average reconstruction error: 0.00743567
# Epoch [2391 / 10000] average reconstruction error: 0.00740085
# Epoch [2401 / 10000] average reconstruction error: 0.00736824
# Epoch [2411 / 10000] average reconstruction error: 0.00733453
# Epoch [2421 / 10000] average reconstruction error: 0.00745239
# Epoch [2431 / 10000] average reconstruction error: 0.00744572
# Epoch [2441 / 10000] average reconstruction error: 0.00728079
# Epoch [2451 / 10000] average reconstruction error: 0.00723360
# Epoch [2461 / 10000] average reconstruction error: 0.00732856
# Epoch [2471 / 10000] average reconstruction error: 0.00731743
# Epoch [2481 / 10000] average reconstruction error: 0.00750457
# Epoch [2491 / 10000] average reconstruction error: 0.08527218
# Epoch [2501 / 10000] average reconstruction error: 0.05063806
# Epoch [2511 / 10000] average reconstruction error: 0.04192997
# Epoch [2521 / 10000] average reconstruction error: 0.03243297
# Epoch [2531 / 10000] average reconstruction error: 0.02967537
# Epoch [2541 / 10000] average reconstruction error: 0.02764314
# Epoch [2551 / 10000] average reconstruction error: 0.02851788
# Epoch [2561 / 10000] average reconstruction error: 0.02581530
# Epoch [2571 / 10000] average reconstruction error: 0.02577985
# Epoch [2581 / 10000] average reconstruction error: 0.02439575
# Epoch [2591 / 10000] average reconstruction error: 0.02339979
# Epoch [2601 / 10000] average reconstruction error: 0.02272053
# Epoch [2611 / 10000] average reconstruction error: 0.02193758
# Epoch [2621 / 10000] average reconstruction error: 0.02107762
# Epoch [2631 / 10000] average reconstruction error: 0.02012284
# Epoch [2641 / 10000] average reconstruction error: 0.01902163
# Epoch [2651 / 10000] average reconstruction error: 0.01773245
# Epoch [2661 / 10000] average reconstruction error: 0.01616964
# Epoch [2671 / 10000] average reconstruction error: 0.01428794
# Epoch [2681 / 10000] average reconstruction error: 0.01224537
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Documents\rpoditela\Intra\autoencoder\autoencoder_5at.ipynb Celda 26 in <cell line: 7>()
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=43'>44</a>     dec_fold_nodes.append(decode_structure_fold_grass(dec_fold, fnode, example))
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=44'>45</a> # Apply the computations on the decoder model
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=47'>48</a> total_loss = dec_fold.apply(Grassdecoder, [dec_fold_nodes])#[0]
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=48'>49</a> #print("total_loss", total_loss)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Documents/rpoditela/Intra/autoencoder/autoencoder_5at.ipynb#X34sZmlsZQ%3D%3D?line=49'>50</a> n_nodes = torch.tensor(n_nodes, device = device)
#
# File c:\Users\User\Documents\rpoditela\Intra\autoencoder\torch_f.py:165, in Fold.apply(self, nn, nodes)
#     163 ##junto los atributos de los nodos que estan en el mismo step y op
#     164 try:
# --> 165     batched_args = self._batch_args(
#     166         zip(*self.steps[step][op]), values, op)
#     167 except Exception:
#     168     print("Error while executing node %s[%d] with args: %s" % (op, step, self.steps[step][op]))
#
# File c:\Users\User\Documents\rpoditela\Intra\autoencoder\torch_f.py:127, in Fold._batch_args(self, arg_lists, values, op)
#     122 else:
#     123     #print("else")
#     124     #si es un tensor de atributos
#     125     if isinstance(arg[0], torch.Tensor):
# --> 127         var = torch.stack(arg)
#     128         res.append(var)
#     130     #si es un nodo de arbol
#     131     else:
#
# KeyboardInterrupt:

# %%
encoder = GRASSEncoder(input_size = 5, feature_size=128, hidden_size=256).to(device)
decoder = GRASSDecoder(latent_size=128, hidden_size=256, mult = mult).to(device)

checkpoint = torch.load("outputs/best_model.pth")
encoder.load_state_dict(checkpoint['encoder_state_dict'])
decoder.load_state_dict(checkpoint['decoder_state_dict'])
epoch = checkpoint['epoch']
print("epoch", epoch)
# Out:
# epoch 8226

# %%
input = iter(data_loader).next()[0]
enc_fold = torch_f.Fold(device)
enc_fold_nodes = []
enc_fold_nodes.append(encode_structure_fold(enc_fold, input))
enc_fold_nodes = enc_fold.apply(encoder, [enc_fold_nodes])
encoded = enc_fold_nodes[0]
decoded = decode_testing_grass(encoded, input, 100, decoder)

count = []
numerar_nodos(decoded, count)
decoded.traverseInorder(decoded)
# Out:
# 0 tensor([[0.5481, 0.4828, 0.2269, 0.2256, 0.9960]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 1 tensor([[0.5020, 0.4501, 0.2851, 0.2304, 0.9773]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 2 tensor([[0.5006, 0.4511, 0.2916, 0.2280, 1.0054]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 3 tensor([[0.5011, 0.4495, 0.2853, 0.2331, 1.0253]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 4 tensor([[0.4984, 0.4469, 0.2797, 0.2389, 1.0412]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 5 tensor([[0.4910, 0.4405, 0.2737, 0.2444, 1.0520]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 6 tensor([[0.4785, 0.4299, 0.2670, 0.2505, 1.0577]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 7 tensor([[0.4602, 0.4148, 0.2598, 0.2578, 1.0583]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 8 tensor([[0.4356, 0.3946, 0.2523, 0.2668, 1.0527]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 9 tensor([[0.4036, 0.3689, 0.2451, 0.2781, 1.0387]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 10 tensor([[0.3637, 0.3369, 0.2391, 0.2919, 1.0120]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 11 tensor([[0.3160, 0.2992, 0.2368, 0.3082, 0.9665]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 12 tensor([[0.2621, 0.2575, 0.2422, 0.3255, 0.8939]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 13 tensor([[0.1426, 0.2405, 0.2103, 0.2135, 0.6354]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 14 tensor([[0.1459, 0.2081, 0.1905, 0.1774, 0.5959]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 15 tensor([[0.1134, 0.1615, 0.1451, 0.1461, 0.6044]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 16 tensor([[0.0885, 0.1336, 0.1108, 0.1434, 0.6174]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 17 tensor([[0.0579, 0.1073, 0.0809, 0.1412, 0.6194]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 18 tensor([[0.0227, 0.0779, 0.0543, 0.1373, 0.6067]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 19 tensor([[-0.0153,  0.0465,  0.0323,  0.1319,  0.5813]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 20 tensor([[-0.0538,  0.0151,  0.0156,  0.1259,  0.5465]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 21 tensor([[-0.0914, -0.0153,  0.0044,  0.1202,  0.5058]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 22 tensor([[-0.1275, -0.0444, -0.0020,  0.1154,  0.4627]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 23 tensor([[-0.1629, -0.0726, -0.0045,  0.1121,  0.4192]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 24 tensor([[-0.1983, -0.1011, -0.0036,  0.1106,  0.3765]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 25 tensor([[-0.2360, -0.1313, -0.0005,  0.1115,  0.3344]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 26 tensor([[-0.2776, -0.1653,  0.0040,  0.1145,  0.2917]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 27 tensor([[-0.3251, -0.2044,  0.0096,  0.1199,  0.2463]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 28 tensor([[0.2053, 0.2140, 0.2611, 0.3401, 0.7862]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 29 tensor([[0.1007, 0.2053, 0.2136, 0.2033, 0.5695]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 30 tensor([[0.1204, 0.1920, 0.1943, 0.1653, 0.5393]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 31 tensor([[0.0933, 0.1472, 0.1457, 0.1330, 0.5506]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 32 tensor([[0.0752, 0.1244, 0.1116, 0.1299, 0.5687]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 33 tensor([[0.0535, 0.1050, 0.0821, 0.1272, 0.5770]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 34 tensor([[0.0291, 0.0840, 0.0563, 0.1226, 0.5723]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 35 tensor([[0.0044, 0.0632, 0.0346, 0.1163, 0.5569]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 36 tensor([[-0.0181,  0.0445,  0.0180,  0.1089,  0.5343]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 37 tensor([[-0.0366,  0.0293,  0.0061,  0.1010,  0.5083]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 38 tensor([[-0.0498,  0.0186, -0.0015,  0.0931,  0.4823]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 39 tensor([[-0.0570,  0.0130, -0.0060,  0.0855,  0.4591]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 40 tensor([[0.1511, 0.1719, 0.2995, 0.3463, 0.6412]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 41 tensor([[0.0585, 0.1665, 0.2171, 0.1932, 0.4974]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 42 tensor([[0.0933, 0.1745, 0.1997, 0.1535, 0.4798]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 43 tensor([[0.0715, 0.1315, 0.1487, 0.1212, 0.4947]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 44 tensor([[0.0593, 0.1130, 0.1150, 0.1184, 0.5187]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 45 tensor([[0.0446, 0.0991, 0.0860, 0.1160, 0.5339]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 46 tensor([[0.0283, 0.0846, 0.0605, 0.1116, 0.5371]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 47 tensor([[0.0129, 0.0710, 0.0390, 0.1054, 0.5307]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 48 tensor([[0.0008, 0.0604, 0.0222, 0.0977, 0.5181]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 49 tensor([[-0.0061,  0.0545,  0.0096,  0.0891,  0.5031]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 50 tensor([[-0.0063,  0.0541,  0.0006,  0.0800,  0.4891]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 51 tensor([[0.1053, 0.1335, 0.3607, 0.3382, 0.4689]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 52 tensor([[0.0211, 0.1286, 0.2208, 0.1845, 0.4283]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 53 tensor([[0.0671, 0.1570, 0.2058, 0.1436, 0.4243]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 54 tensor([[0.0494, 0.1154, 0.1533, 0.1121, 0.4429]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 55 tensor([[0.0413, 0.0999, 0.1201, 0.1100, 0.4724]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 56 tensor([[0.0309, 0.0893, 0.0917, 0.1085, 0.4936]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 57 tensor([[0.0188, 0.0781, 0.0663, 0.1050, 0.5032]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 58 tensor([[0.0076, 0.0677, 0.0448, 0.0997, 0.5036]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 59 tensor([[-4.6044e-04,  6.0290e-02,  2.7603e-02,  9.2785e-02,  4.9757e-01]],
#        device='cuda:0', grad_fn=<AddmmBackward0>)
# 60 tensor([[-0.0035,  0.0572,  0.0143,  0.0849,  0.4888]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 61 tensor([[0.0732, 0.1015, 0.4409, 0.3154, 0.2927]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 62 tensor([[-0.0076,  0.0962,  0.2238,  0.1785,  0.3723]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 63 tensor([[0.0444, 0.1415, 0.2108, 0.1368, 0.3798]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 64 tensor([[0.0288, 0.1001, 0.1578, 0.1062, 0.4011]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 65 tensor([[0.0575, 0.0784, 0.5287, 0.2849, 0.1400]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 66 tensor([[0.0574, 0.0662, 0.6104, 0.2564, 0.0298]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 67 tensor([[ 0.0689,  0.0648,  0.6759,  0.2362, -0.0356]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 68 tensor([[0.5681, 0.4889, 0.2238, 0.2117, 1.0080]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 69 tensor([[0.6014, 0.5231, 0.2217, 0.1628, 1.0193]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 70 tensor([[0.5877, 0.5317, 0.1738, 0.1485, 1.0026]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 71 tensor([[0.6152, 0.5531, 0.1619, 0.1384, 0.9908]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 72 tensor([[0.6397, 0.5769, 0.1574, 0.1307, 0.9803]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 73 tensor([[0.6595, 0.5960, 0.1534, 0.1256, 0.9751]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 74 tensor([[0.6754, 0.6116, 0.1512, 0.1236, 0.9746]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 75 tensor([[0.6886, 0.6246, 0.1513, 0.1235, 0.9772]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 76 tensor([[0.7003, 0.6358, 0.1536, 0.1246, 0.9811]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 77 tensor([[0.7117, 0.6463, 0.1580, 0.1262, 0.9854]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 78 tensor([[0.7229, 0.6565, 0.1641, 0.1279, 0.9893]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 79 tensor([[0.7341, 0.6667, 0.1715, 0.1298, 0.9930]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 80 tensor([[0.7459, 0.6769, 0.1801, 0.1316, 0.9964]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 81 tensor([[0.7582, 0.6879, 0.1898, 0.1336, 0.9995]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 82 tensor([[0.7712, 0.6992, 0.2005, 0.1353, 1.0024]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 83 tensor([[0.7851, 0.7114, 0.2122, 0.1373, 1.0049]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 84 tensor([[0.8000, 0.7246, 0.2253, 0.1391, 1.0073]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 85 tensor([[0.8158, 0.7386, 0.2393, 0.1411, 1.0093]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 86 tensor([[0.8327, 0.7535, 0.2547, 0.1429, 1.0112]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 87 tensor([[0.8507, 0.7692, 0.2711, 0.1448, 1.0126]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 88 tensor([[0.8696, 0.7862, 0.2889, 0.1466, 1.0137]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 89 tensor([[0.8894, 0.8038, 0.3077, 0.1485, 1.0141]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 90 tensor([[0.9099, 0.8219, 0.3275, 0.1502, 1.0140]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 91 tensor([[0.9305, 0.8404, 0.3480, 0.1515, 1.0131]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 92 tensor([[0.9511, 0.8590, 0.3688, 0.1528, 1.0115]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 93 tensor([[0.9710, 0.8769, 0.3895, 0.1537, 1.0095]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 94 tensor([[0.9899, 0.8939, 0.4096, 0.1544, 1.0070]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# 95 tensor([[1.0072, 0.9096, 0.4284, 0.1550, 1.0037]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)

# %%
plotTree(input, False)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.5, 0.5,…

# %%
plotTree(decoded, True)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.3410439…

# %%
c = []
n_nodes = input.count_nodes(input,c)
len(n_nodes)
# Out:
# 70

# %%
c = []
n_nodes = decoded.count_nodes(decoded,c)
len(n_nodes)
# Out:
# 101

# %%
li = []
decoded.traverseInorderChilds(decoded, li)
zero = [a for a in li if a == 0]
one = [a for a in li if a == 1]
two = [a for a in li if a == 2]
qzero = len(zero)
qOne = len(one)
qtwo = len(two)
print(qzero, qOne, qtwo)
# Out:
# 8 86 7

# %%
li = []
input.traverseInorderChilds(input, li)
zero = [a for a in li if a == 0]
one = [a for a in li if a == 1]
two = [a for a in li if a == 2]
qzero = len(zero)
qOne = len(one)
qtwo = len(two)
print(qzero, qOne, qtwo)
# Out:
# 3 65 2

# %%
def traverseleaf(root):
    if root is not None:
        traverseleaf(root.left)
        if root.is_leaf():
            print(root.radius)
        traverseleaf(root.right)
        return 

def traversebif(root):
    if root is not None:
        traversebif(root.left)
        if root.is_two_child():
            print(root.radius)
        traversebif(root.right)
        return

# %%
traversebif(decoded)
print("////")
traversebif(input)
# Out:
# tensor([[-0.7837, -0.6266,  0.0326,  0.0245, -0.3967]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.7638, -0.6124,  0.0773,  0.0227, -0.4341]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.7258, -0.5825,  0.1320,  0.0219, -0.4631]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.1291, 0.1595, 0.3353, 0.3775, 0.6678]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.0774, 0.1162, 0.4071, 0.3557, 0.4535]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.0511, 0.0857, 0.4979, 0.3109, 0.2374]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[0.5820, 0.5106, 0.2151, 0.1909, 1.0082]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ////
# tensor([0.1163, 0.1714, 0.2870, 1.0000, 0.0000], device='cuda:0')
# tensor([0.5789, 0.5054, 0.2145, 0.1945, 1.0000], device='cuda:0')

# %%
traverseleaf(decoded)
print("////")
traverseleaf(input)
# Out:
# tensor([[-0.0255,  0.0094,  0.2481, -0.1010, -0.1502]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0363,  0.0043,  0.2453, -0.0897, -0.1417]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.0450,  0.0009,  0.2424, -0.0737, -0.1244]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[-0.6703, -0.5375,  0.1971,  0.0231, -0.4818]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[ 0.0140,  0.0626, -0.0253,  0.0198,  0.4396]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[ 0.0520,  0.0934, -0.0147,  0.0243,  0.4704]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[ 0.0886,  0.0770,  0.6952,  0.2157, -0.0649]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# tensor([[1.0117, 0.9053, 0.4411, 0.1564, 1.0207]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ////
# tensor([0.0446, 0.0000, 0.0000, 0.0500, 0.5000], device='cuda:0')
# tensor([0.0634, 0.1035, 1.0000, 0.3390, 0.0000], device='cuda:0')
# tensor([0.9985, 1.0000, 0.6220, 0.2447, 1.0000], device='cuda:0')
